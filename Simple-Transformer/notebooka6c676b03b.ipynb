# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os

for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/training-datasets/deu_english.txt
# /kaggle/input/training-datasets/deu_german.txt

# %%
import io
import pickle
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow.keras import layers
from tensorflow.keras.layers import Dense, Dropout, LayerNormalization
from tensorflow.keras.metrics import SparseCategoricalAccuracy
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.preprocessing.text import Tokenizer

# %%
def load_data(file1, file2):
    with io.open(file1, mode='r', encoding='utf-8') as f1, io.open(file2, mode='r', encoding='utf-8') as f2:
        english_sentences = [line.strip() for line in f1]
        german_sentences = ["<start> " + line.strip() + " <end>" for line in f2]

    return english_sentences, german_sentences

def preprocess_data(english_sentences, german_sentences, max_seq_length=None):
    def tokenize_and_pad(sentences, max_len=None):
        tokenizer = Tokenizer(filters='', lower=False)
        tokenizer.fit_on_texts(sentences)
        sequences = tokenizer.texts_to_sequences(sentences)

        if max_len is None:
            max_len = max(len(seq) for seq in sequences)

        padded_sequences = pad_sequences(sequences, maxlen=max_len, padding='post')

        return tokenizer, padded_sequences

    english_tokenizer, tokenized_english = tokenize_and_pad(english_sentences)
    max_len = max_seq_length if max_seq_length is not None else max(len(seq) for seq in tokenized_english)
    german_tokenizer, tokenized_german = tokenize_and_pad(german_sentences, max_len)

    return (english_tokenizer, tokenized_english), (german_tokenizer, tokenized_german), max_len



def split_data(tokenized_english, tokenized_german, train_ratio):

    # Randomize the order of sentences while maintaining correspondence
    combined_data = list(zip(tokenized_english, tokenized_german))
    np.random.shuffle(combined_data)
    shuffled_english, shuffled_german = zip(*combined_data)

    # Split the data into training and validation sets
    split_index = int(len(shuffled_english) * train_ratio)
    train_english, val_english = shuffled_english[:split_index], shuffled_english[split_index:]
    train_german, val_german = shuffled_german[:split_index], shuffled_german[split_index:]

    return train_english, train_german, val_english, val_german

def create_optimizer(learning_rate):


    # Create the Adam optimizer with the given learning rate
    optimizer = tf.keras.optimizers.Adam(learning_rate=learning_rate)

    return optimizer

class PositionalEncoding(tf.keras.layers.Layer):
    def __init__(self, hidden_units):
        super(PositionalEncoding, self).__init__()
        self.hidden_units = hidden_units

    def build(self, input_shape):
        self.positional_encoding = self._create_positional_encoding(input_shape[1])

    def call(self, inputs):
        return inputs + self.positional_encoding

    def _create_positional_encoding(self, length):
        positional_encoding = np.zeros((1, length, self.hidden_units), dtype=np.float32)
        for pos in range(length):
            for i in range(0, self.hidden_units, 2):
                angle = pos / np.power(10000, (2 * i) / self.hidden_units)
                positional_encoding[:, pos, i] = np.sin(angle)
                positional_encoding[:, pos, i + 1] = np.cos(angle)
        return tf.constant(positional_encoding)
    
class TransformerModel(tf.keras.Model):
    def __init__(self, num_layers, attention_heads, hidden_units, dropout_rate,
                 input_vocab_size, target_vocab_size, max_seq_length, **kwargs):
        super(TransformerModel, self).__init__(**kwargs)
        self.num_layers = num_layers
        self.attention_heads = attention_heads
        self.hidden_units = hidden_units
        self.dropout_rate = dropout_rate
        self.encoder_inputs = tf.keras.Input(shape=(max_seq_length,), dtype=tf.int32, name="encoder_inputs")
        self.decoder_inputs = tf.keras.Input(shape=(max_seq_length,), dtype=tf.int32, name="decoder_inputs")
        
        # Encoder
        self.encoder_embedding = tf.keras.layers.Embedding(input_vocab_size, self.hidden_units)
        self.encoder_positional_encoding = PositionalEncoding(self.hidden_units)
        self.encoder_layers = []
        for _ in range(self.num_layers):
            self.encoder_layers.extend([
                layers.MultiHeadAttention(num_heads=self.attention_heads, key_dim=self.hidden_units),
                Dropout(self.dropout_rate),
                LayerNormalization(epsilon=1e-6),
                Dense(self.hidden_units * 4, activation="relu"),
                Dropout(self.dropout_rate),
                Dense(self.hidden_units),
                LayerNormalization(epsilon=1e-6)
            ])

        # Decoder
        self.decoder_embedding = tf.keras.layers.Embedding(target_vocab_size, self.hidden_units)
        self.decoder_positional_encoding = PositionalEncoding(self.hidden_units)
        self.decoder_layers = []
        for _ in range(self.num_layers):
            self.decoder_layers.extend([
                layers.MultiHeadAttention(num_heads=self.attention_heads, key_dim=self.hidden_units),
                Dropout(self.dropout_rate),
                LayerNormalization(epsilon=1e-6),
                layers.MultiHeadAttention(num_heads=self.attention_heads, key_dim=self.hidden_units),
                Dropout(self.dropout_rate),
                LayerNormalization(epsilon=1e-6),
                Dense(self.hidden_units * 4, activation="relu"),
                Dropout(self.dropout_rate),
                Dense(self.hidden_units),
                LayerNormalization(epsilon=1e-6)
            ])

        # Output layer
        self.output_layer = Dense(target_vocab_size) # The softmax activation was removed.

    def call(self, inputs):
        encoder_inputs, decoder_inputs = inputs
        encoder = self.encoder_embedding(encoder_inputs)
        encoder = self.encoder_positional_encoding(encoder)

        for i in range(0, len(self.encoder_layers), 7):
            attention_output = self.encoder_layers[i](query=encoder, key=encoder, value=encoder)
            attention_output = self.encoder_layers[i+1](attention_output)
            encoder = layers.Add()([encoder, attention_output])
            encoder = self.encoder_layers[i+2](encoder)

            mlp_output = self.encoder_layers[i+3](encoder)
            mlp_output = self.encoder_layers[i+4](mlp_output)
            mlp_output = self.encoder_layers[i+5](mlp_output)
            encoder = layers.Add()([encoder, mlp_output])

        decoder = self.decoder_embedding(decoder_inputs)
        decoder = self.decoder_positional_encoding(decoder)

        for i in range(0, len(self.decoder_layers), 10):
            attention_output = self.decoder_layers[i](query=decoder, key=decoder, value=decoder)
            attention_output = self.decoder_layers[i+1](attention_output)
            decoder = layers.Add()([decoder, attention_output])
            decoder = self.decoder_layers[i+2](decoder)

            attention_output = self.decoder_layers[i+3](query=decoder, key=encoder, value=encoder)
            attention_output = self.decoder_layers[i+4](attention_output)
            decoder = layers.Add()([decoder, attention_output])
            decoder = self.decoder_layers[i+5](decoder)

            mlp_output = self.decoder_layers[i+6](decoder)
            mlp_output = self.decoder_layers[i+7](mlp_output)
            mlp_output = self.decoder_layers[i+8](mlp_output)
            decoder = layers.Add()([decoder, mlp_output])

        outputs = self.output_layer(decoder)
        return outputs
    
def apply_gradient_clipping(optimizer, model, loss_object, clip_norm=1.0):
    original_apply_gradients = optimizer.apply_gradients

    def apply_gradients_with_clipping(grads_and_vars, *args, **kwargs):
        clipped_grads_and_vars = [(tf.clip_by_norm(grad, clip_norm), var) for grad, var in grads_and_vars]
        return original_apply_gradients(clipped_grads_and_vars, *args, **kwargs)

    optimizer.apply_gradients = apply_gradients_with_clipping
    return optimizer

def configure_learning_rate_scheduler(optimizer, warmup_steps):
    # Set the initial learning rate
    initial_learning_rate = 0.001

    # Set the maximum learning rate
    max_learning_rate = 0.01

    # Define the linear learning rate scheduler with warmup
    def scheduler(epoch, lr):
        if epoch < warmup_steps:
            return initial_learning_rate + (epoch * (max_learning_rate - initial_learning_rate) / warmup_steps)
        else:
            return max_learning_rate - (epoch - warmup_steps) * (max_learning_rate - initial_learning_rate) / (total_epochs - warmup_steps)

    # Create the learning rate scheduler
    learning_rate_scheduler = tf.keras.callbacks.LearningRateScheduler(schedule=scheduler)

    return learning_rate_scheduler


def print_variable(variable_name, variable_value):
    print(f"{variable_name}: {variable_value}, Type: {type(variable_value)}")

def train_model(model, train_english, train_german, val_english, val_german, epochs, optimizer, scheduler):
    print_variable("model", model)

    loss_object = tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True, reduction='none')

    def loss_function(real, pred):
        mask = tf.math.logical_not(tf.math.equal(real, 0))
        loss_ = loss_object(real, pred)

        mask = tf.cast(mask, dtype=loss_.dtype)
        loss_ *= mask

        return tf.reduce_sum(loss_)/tf.reduce_sum(mask)

    train_loss = tf.keras.metrics.Mean(name='train_loss')
    train_accuracy = SparseCategoricalAccuracy(name='train_accuracy')

    @tf.function
    def train_step(inp, tar):
        #print("\ntar before: ", tar.shape)
        tar_inp = tar[:, :-1]
        #print("\ntar input: ", tar_inp.shape)
        tar_real = tar[:, 1:]
        #print("\n input shape: ", inp.shape)

        with tf.GradientTape() as tape:
            predictions = model((inp, tar_inp), training=True)
            loss = loss_function(tar_real, predictions)

        gradients = tape.gradient(loss, model.trainable_variables)
        optimizer.apply_gradients(zip(gradients, model.trainable_variables))
        train_loss(loss)
        train_accuracy(tar_real, predictions)

    checkpoint_dir = './model_checkpoints'
    checkpoint_prefix = os.path.join(checkpoint_dir, "ckpt")
    checkpoint = tf.train.Checkpoint(optimizer=optimizer, model=model)

    batch_size = 64  # You can change this value according to your available resources
    print("\nBatch size is: ", batch_size)
    
    print("\Defining datasets (train, val)\n")
    train_dataset = tf.data.Dataset.from_tensor_slices((train_english, train_german)).shuffle(len(train_english)).batch(batch_size, drop_remainder=True)
    print("Dataset shuffled\n")
    val_dataset = tf.data.Dataset.from_tensor_slices((val_english, val_german)).batch(batch_size, drop_remainder=True)


    print("\nThe training begins\n")
    for epoch in range(epochs):
        train_loss.reset_states()
        train_accuracy.reset_states()

        for (batch, (inp, tar)) in enumerate(train_dataset):
            train_step(inp, tar)
            print(f'Epoch {epoch + 1} Batch {batch} Loss {train_loss.result():.4f} Accuracy {train_accuracy.result():.4f}')

        if (epoch + 1) % 5 == 0:
            checkpoint.save(file_prefix=checkpoint_prefix)

        print(f'Epoch {epoch + 1} Loss {train_loss.result():.4f} Accuracy {train_accuracy.result():.4f}')

    final_model_name = "SimpleTransformerWeights"
    model.save_weights(final_model_name)

    return model


print("The main function final\n\n\n")
# Load, preprocess, and split data
english_sentences, german_sentences = load_data("/kaggle/input/training-datasets/deu_english.txt", "/kaggle/input/training-datasets/deu_german.txt")
max_seq_length = None
(english_tokenizer, tokenized_english), (german_tokenizer, tokenized_german), max_len = preprocess_data(english_sentences, german_sentences, max_seq_length)
print("\n Max sequence length: ", max_len, "\n")
train_ratio = 1
train_english, train_german, val_english, val_german = split_data(tokenized_english, tokenized_german, train_ratio)

# Convert the train_english, train_german, val_english, and val_german data to tensors
train_english = tf.convert_to_tensor(np.array(train_english))
train_german = tf.convert_to_tensor(np.array(train_german))
val_english = tf.convert_to_tensor(np.array(val_english))
val_german = tf.convert_to_tensor(np.array(val_german))


# Initialize the transformer model
num_layers = 2
attention_heads = 8
hidden_units = 64
dropout_rate = 0.1
input_vocab_size = len(english_tokenizer.word_index) + 1
target_vocab_size = len(german_tokenizer.word_index) + 1

model = TransformerModel(num_layers, attention_heads, hidden_units, dropout_rate, input_vocab_size, target_vocab_size, max_seq_length)

# Create and configure the optimizer with gradient clipping and learning rate scheduler
learning_rate = 0.001
optimizer = create_optimizer(learning_rate)
optimizer_with_clipping = apply_gradient_clipping(optimizer, model, tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True, reduction="none"))
warmup_steps = 3
scheduler = configure_learning_rate_scheduler(optimizer_with_clipping, warmup_steps)

# Train the model
epochs = 10
trained_model = train_model(model, train_english, train_german, val_english, val_german, epochs, optimizer, scheduler)

# Save max_len, english_tokenizer, and german_tokenizer
with open('max_len.pkl', 'wb') as f:
    pickle.dump(max_len, f)

with open('english_tokenizer.pkl', 'wb') as f:
    pickle.dump(english_tokenizer, f)

with open('german_tokenizer.pkl', 'wb') as f:
    pickle.dump(german_tokenizer, f)
# Out:
# The main function final
#
#
#
#
#  Max sequence length:  101
#
# model: <__main__.TransformerModel object at 0x729b1d7bf6d0>, Type: <class '__main__.TransformerModel'>
#
# Batch size is:  64
# \Defining datasets (train, val)
#
# Dataset shuffled
#
#
# The training begins
#
# Epoch 1 Batch 0 Loss 11.1040 Accuracy 0.0000
# Epoch 1 Batch 1 Loss 11.0600 Accuracy 0.0050
# Epoch 1 Batch 2 Loss 11.0207 Accuracy 0.0067
# Epoch 1 Batch 3 Loss 10.9748 Accuracy 0.0075
# Epoch 1 Batch 4 Loss 10.9261 Accuracy 0.0080
# Epoch 1 Batch 5 Loss 10.8722 Accuracy 0.0083
# Epoch 1 Batch 6 Loss 10.8119 Accuracy 0.0086
# Epoch 1 Batch 7 Loss 10.7414 Accuracy 0.0088
# Epoch 1 Batch 8 Loss 10.6565 Accuracy 0.0089
# Epoch 1 Batch 9 Loss 10.5731 Accuracy 0.0090
# Epoch 1 Batch 10 Loss 10.4763 Accuracy 0.0091
# Epoch 1 Batch 11 Loss 10.3758 Accuracy 0.0092
# Epoch 1 Batch 12 Loss 10.2591 Accuracy 0.0092
# Epoch 1 Batch 13 Loss 10.1479 Accuracy 0.0093
# Epoch 1 Batch 14 Loss 10.0147 Accuracy 0.0093
# Epoch 1 Batch 15 Loss 9.8838 Accuracy 0.0094
# Epoch 1 Batch 16 Loss 9.7451 Accuracy 0.0094
# Epoch 1 Batch 17 Loss 9.6095 Accuracy 0.0094
# Epoch 1 Batch 18 Loss 9.4945 Accuracy 0.0095
# Epoch 1 Batch 19 Loss 9.3925 Accuracy 0.0095
# Epoch 1 Batch 20 Loss 9.3006 Accuracy 0.0095
# Epoch 1 Batch 21 Loss 9.2136 Accuracy 0.0095
# Epoch 1 Batch 22 Loss 9.1545 Accuracy 0.0096
# Epoch 1 Batch 23 Loss 9.0703 Accuracy 0.0096
# Epoch 1 Batch 24 Loss 9.0027 Accuracy 0.0096
# Epoch 1 Batch 25 Loss 8.9435 Accuracy 0.0096
# Epoch 1 Batch 26 Loss 8.8898 Accuracy 0.0096
# Epoch 1 Batch 27 Loss 8.8271 Accuracy 0.0096
# Epoch 1 Batch 28 Loss 8.7633 Accuracy 0.0097
# Epoch 1 Batch 29 Loss 8.7093 Accuracy 0.0097
# Epoch 1 Batch 30 Loss 8.6647 Accuracy 0.0097
# Epoch 1 Batch 31 Loss 8.6243 Accuracy 0.0097
# Epoch 1 Batch 32 Loss 8.5777 Accuracy 0.0097
# Epoch 1 Batch 33 Loss 8.5346 Accuracy 0.0097
# Epoch 1 Batch 34 Loss 8.4986 Accuracy 0.0097
# Epoch 1 Batch 35 Loss 8.4623 Accuracy 0.0097
# Epoch 1 Batch 36 Loss 8.4245 Accuracy 0.0097
# Epoch 1 Batch 37 Loss 8.3872 Accuracy 0.0097
# Epoch 1 Batch 38 Loss 8.3573 Accuracy 0.0097
# Epoch 1 Batch 39 Loss 8.3253 Accuracy 0.0098
# Epoch 1 Batch 40 Loss 8.2974 Accuracy 0.0098
# Epoch 1 Batch 41 Loss 8.2707 Accuracy 0.0098
# Epoch 1 Batch 42 Loss 8.2473 Accuracy 0.0098
# Epoch 1 Batch 43 Loss 8.2190 Accuracy 0.0098
# Epoch 1 Batch 44 Loss 8.1963 Accuracy 0.0098
# Epoch 1 Batch 45 Loss 8.1739 Accuracy 0.0098
# Epoch 1 Batch 46 Loss 8.1490 Accuracy 0.0098
# Epoch 1 Batch 47 Loss 8.1240 Accuracy 0.0098
# Epoch 1 Batch 48 Loss 8.1026 Accuracy 0.0098
# Epoch 1 Batch 49 Loss 8.0822 Accuracy 0.0098
# Epoch 1 Batch 50 Loss 8.0629 Accuracy 0.0098
# Epoch 1 Batch 51 Loss 8.0461 Accuracy 0.0098
# Epoch 1 Batch 52 Loss 8.0314 Accuracy 0.0098
# Epoch 1 Batch 53 Loss 8.0128 Accuracy 0.0098
# Epoch 1 Batch 54 Loss 7.9950 Accuracy 0.0098
# Epoch 1 Batch 55 Loss 7.9799 Accuracy 0.0098
# Epoch 1 Batch 56 Loss 7.9624 Accuracy 0.0098
# Epoch 1 Batch 57 Loss 7.9464 Accuracy 0.0098
# Epoch 1 Batch 58 Loss 7.9361 Accuracy 0.0098
# Epoch 1 Batch 59 Loss 7.9214 Accuracy 0.0098
# Epoch 1 Batch 60 Loss 7.9082 Accuracy 0.0098
# Epoch 1 Batch 61 Loss 7.8930 Accuracy 0.0098
# Epoch 1 Batch 62 Loss 7.8776 Accuracy 0.0098
# Epoch 1 Batch 63 Loss 7.8671 Accuracy 0.0098
# Epoch 1 Batch 64 Loss 7.8549 Accuracy 0.0098
# Epoch 1 Batch 65 Loss 7.8478 Accuracy 0.0098
# Epoch 1 Batch 66 Loss 7.8356 Accuracy 0.0099
# Epoch 1 Batch 67 Loss 7.8242 Accuracy 0.0099
# Epoch 1 Batch 68 Loss 7.8121 Accuracy 0.0099
# Epoch 1 Batch 69 Loss 7.8035 Accuracy 0.0099
# Epoch 1 Batch 70 Loss 7.7970 Accuracy 0.0099
# Epoch 1 Batch 71 Loss 7.7878 Accuracy 0.0099
# Epoch 1 Batch 72 Loss 7.7784 Accuracy 0.0099
# Epoch 1 Batch 73 Loss 7.7671 Accuracy 0.0099
# Epoch 1 Batch 74 Loss 7.7549 Accuracy 0.0099
# Epoch 1 Batch 75 Loss 7.7468 Accuracy 0.0099
# Epoch 1 Batch 76 Loss 7.7372 Accuracy 0.0099
# Epoch 1 Batch 77 Loss 7.7301 Accuracy 0.0099
# Epoch 1 Batch 78 Loss 7.7242 Accuracy 0.0099
# Epoch 1 Batch 79 Loss 7.7177 Accuracy 0.0099
# Epoch 1 Batch 80 Loss 7.7089 Accuracy 0.0099
# Epoch 1 Batch 81 Loss 7.7015 Accuracy 0.0099
# Epoch 1 Batch 82 Loss 7.6939 Accuracy 0.0099
# Epoch 1 Batch 83 Loss 7.6867 Accuracy 0.0099
# Epoch 1 Batch 84 Loss 7.6782 Accuracy 0.0099
# Epoch 1 Batch 85 Loss 7.6721 Accuracy 0.0099
# Epoch 1 Batch 86 Loss 7.6656 Accuracy 0.0099
# Epoch 1 Batch 87 Loss 7.6579 Accuracy 0.0099
# Epoch 1 Batch 88 Loss 7.6497 Accuracy 0.0099
# Epoch 1 Batch 89 Loss 7.6435 Accuracy 0.0099
# Epoch 1 Batch 90 Loss 7.6396 Accuracy 0.0099
# Epoch 1 Batch 91 Loss 7.6329 Accuracy 0.0099
# Epoch 1 Batch 92 Loss 7.6273 Accuracy 0.0099
# Epoch 1 Batch 93 Loss 7.6214 Accuracy 0.0099
# Epoch 1 Batch 94 Loss 7.6167 Accuracy 0.0099
# Epoch 1 Batch 95 Loss 7.6094 Accuracy 0.0099
# Epoch 1 Batch 96 Loss 7.6027 Accuracy 0.0099
# Epoch 1 Batch 97 Loss 7.5973 Accuracy 0.0099
# Epoch 1 Batch 98 Loss 7.5892 Accuracy 0.0099
# Epoch 1 Batch 99 Loss 7.5806 Accuracy 0.0099
# Epoch 1 Batch 100 Loss 7.5753 Accuracy 0.0099
# Epoch 1 Batch 101 Loss 7.5695 Accuracy 0.0099
# Epoch 1 Batch 102 Loss 7.5649 Accuracy 0.0099
# Epoch 1 Batch 103 Loss 7.5611 Accuracy 0.0099
# Epoch 1 Batch 104 Loss 7.5556 Accuracy 0.0099
# Epoch 1 Batch 105 Loss 7.5525 Accuracy 0.0099
# Epoch 1 Batch 106 Loss 7.5492 Accuracy 0.0099
# Epoch 1 Batch 107 Loss 7.5446 Accuracy 0.0099
# Epoch 1 Batch 108 Loss 7.5392 Accuracy 0.0099
# Epoch 1 Batch 109 Loss 7.5330 Accuracy 0.0099
# Epoch 1 Batch 110 Loss 7.5281 Accuracy 0.0099
# Epoch 1 Batch 111 Loss 7.5216 Accuracy 0.0099
# Epoch 1 Batch 112 Loss 7.5157 Accuracy 0.0099
# Epoch 1 Batch 113 Loss 7.5099 Accuracy 0.0099
# Epoch 1 Batch 114 Loss 7.5050 Accuracy 0.0099
# Epoch 1 Batch 115 Loss 7.4999 Accuracy 0.0099
# Epoch 1 Batch 116 Loss 7.4963 Accuracy 0.0099
# Epoch 1 Batch 117 Loss 7.4918 Accuracy 0.0099
# Epoch 1 Batch 118 Loss 7.4873 Accuracy 0.0099
# Epoch 1 Batch 119 Loss 7.4823 Accuracy 0.0099
# Epoch 1 Batch 120 Loss 7.4780 Accuracy 0.0099
# Epoch 1 Batch 121 Loss 7.4743 Accuracy 0.0099
# Epoch 1 Batch 122 Loss 7.4707 Accuracy 0.0099
# Epoch 1 Batch 123 Loss 7.4668 Accuracy 0.0099
# Epoch 1 Batch 124 Loss 7.4630 Accuracy 0.0099
# Epoch 1 Batch 125 Loss 7.4601 Accuracy 0.0099
# Epoch 1 Batch 126 Loss 7.4582 Accuracy 0.0099
# Epoch 1 Batch 127 Loss 7.4544 Accuracy 0.0099
# Epoch 1 Batch 128 Loss 7.4507 Accuracy 0.0099
# Epoch 1 Batch 129 Loss 7.4471 Accuracy 0.0099
# Epoch 1 Batch 130 Loss 7.4442 Accuracy 0.0099
# Epoch 1 Batch 131 Loss 7.4417 Accuracy 0.0099
# Epoch 1 Batch 132 Loss 7.4371 Accuracy 0.0099
# Epoch 1 Batch 133 Loss 7.4334 Accuracy 0.0099
# Epoch 1 Batch 134 Loss 7.4290 Accuracy 0.0099
# Epoch 1 Batch 135 Loss 7.4261 Accuracy 0.0099
# Epoch 1 Batch 136 Loss 7.4237 Accuracy 0.0099
# Epoch 1 Batch 137 Loss 7.4204 Accuracy 0.0099
# Epoch 1 Batch 138 Loss 7.4173 Accuracy 0.0099
# Epoch 1 Batch 139 Loss 7.4148 Accuracy 0.0099
# Epoch 1 Batch 140 Loss 7.4130 Accuracy 0.0099
# Epoch 1 Batch 141 Loss 7.4103 Accuracy 0.0099
# Epoch 1 Batch 142 Loss 7.4074 Accuracy 0.0099
# Epoch 1 Batch 143 Loss 7.4052 Accuracy 0.0099
# Epoch 1 Batch 144 Loss 7.4026 Accuracy 0.0099
# Epoch 1 Batch 145 Loss 7.3980 Accuracy 0.0099
# Epoch 1 Batch 146 Loss 7.3940 Accuracy 0.0099
# Epoch 1 Batch 147 Loss 7.3913 Accuracy 0.0099
# Epoch 1 Batch 148 Loss 7.3892 Accuracy 0.0099
# Epoch 1 Batch 149 Loss 7.3856 Accuracy 0.0099
# Epoch 1 Batch 150 Loss 7.3829 Accuracy 0.0099
# Epoch 1 Batch 151 Loss 7.3793 Accuracy 0.0099
# Epoch 1 Batch 152 Loss 7.3755 Accuracy 0.0099
# Epoch 1 Batch 153 Loss 7.3723 Accuracy 0.0099
# Epoch 1 Batch 154 Loss 7.3692 Accuracy 0.0099
# Epoch 1 Batch 155 Loss 7.3668 Accuracy 0.0099
# Epoch 1 Batch 156 Loss 7.3633 Accuracy 0.0099
# Epoch 1 Batch 157 Loss 7.3598 Accuracy 0.0099
# Epoch 1 Batch 158 Loss 7.3577 Accuracy 0.0099
# Epoch 1 Batch 159 Loss 7.3553 Accuracy 0.0099
# Epoch 1 Batch 160 Loss 7.3534 Accuracy 0.0099
# Epoch 1 Batch 161 Loss 7.3515 Accuracy 0.0099
# Epoch 1 Batch 162 Loss 7.3489 Accuracy 0.0099
# Epoch 1 Batch 163 Loss 7.3463 Accuracy 0.0099
# Epoch 1 Batch 164 Loss 7.3433 Accuracy 0.0099
# Epoch 1 Batch 165 Loss 7.3421 Accuracy 0.0099
# Epoch 1 Batch 166 Loss 7.3407 Accuracy 0.0099
# Epoch 1 Batch 167 Loss 7.3393 Accuracy 0.0099
# Epoch 1 Batch 168 Loss 7.3385 Accuracy 0.0099
# Epoch 1 Batch 169 Loss 7.3366 Accuracy 0.0099
# Epoch 1 Batch 170 Loss 7.3345 Accuracy 0.0099
# Epoch 1 Batch 171 Loss 7.3324 Accuracy 0.0099
# Epoch 1 Batch 172 Loss 7.3297 Accuracy 0.0099
# Epoch 1 Batch 173 Loss 7.3274 Accuracy 0.0099
# Epoch 1 Batch 174 Loss 7.3252 Accuracy 0.0099
# Epoch 1 Batch 175 Loss 7.3235 Accuracy 0.0099
# Epoch 1 Batch 176 Loss 7.3217 Accuracy 0.0099
# Epoch 1 Batch 177 Loss 7.3191 Accuracy 0.0099
# Epoch 1 Batch 178 Loss 7.3183 Accuracy 0.0099
# Epoch 1 Batch 179 Loss 7.3165 Accuracy 0.0099
# Epoch 1 Batch 180 Loss 7.3134 Accuracy 0.0099
# Epoch 1 Batch 181 Loss 7.3098 Accuracy 0.0099
# Epoch 1 Batch 182 Loss 7.3074 Accuracy 0.0099
# Epoch 1 Batch 183 Loss 7.3066 Accuracy 0.0099
# Epoch 1 Batch 184 Loss 7.3043 Accuracy 0.0099
# Epoch 1 Batch 185 Loss 7.3017 Accuracy 0.0099
# Epoch 1 Batch 186 Loss 7.3006 Accuracy 0.0099
# Epoch 1 Batch 187 Loss 7.2997 Accuracy 0.0099
# Epoch 1 Batch 188 Loss 7.2970 Accuracy 0.0099
# Epoch 1 Batch 189 Loss 7.2953 Accuracy 0.0099
# Epoch 1 Batch 190 Loss 7.2942 Accuracy 0.0099
# Epoch 1 Batch 191 Loss 7.2917 Accuracy 0.0099
# Epoch 1 Batch 192 Loss 7.2897 Accuracy 0.0099
# Epoch 1 Batch 193 Loss 7.2867 Accuracy 0.0099
# Epoch 1 Batch 194 Loss 7.2851 Accuracy 0.0099
# Epoch 1 Batch 195 Loss 7.2840 Accuracy 0.0099
# Epoch 1 Batch 196 Loss 7.2829 Accuracy 0.0099
# Epoch 1 Batch 197 Loss 7.2812 Accuracy 0.0099
# Epoch 1 Batch 198 Loss 7.2784 Accuracy 0.0099
# Epoch 1 Batch 199 Loss 7.2755 Accuracy 0.0099
# Epoch 1 Batch 200 Loss 7.2731 Accuracy 0.0100
# Epoch 1 Batch 201 Loss 7.2705 Accuracy 0.0100
# Epoch 1 Batch 202 Loss 7.2674 Accuracy 0.0100
# Epoch 1 Batch 203 Loss 7.2652 Accuracy 0.0100
# Epoch 1 Batch 204 Loss 7.2620 Accuracy 0.0100
# Epoch 1 Batch 205 Loss 7.2591 Accuracy 0.0100
# Epoch 1 Batch 206 Loss 7.2557 Accuracy 0.0100
# Epoch 1 Batch 207 Loss 7.2537 Accuracy 0.0100
# Epoch 1 Batch 208 Loss 7.2505 Accuracy 0.0100
# Epoch 1 Batch 209 Loss 7.2479 Accuracy 0.0100
# Epoch 1 Batch 210 Loss 7.2464 Accuracy 0.0100
# Epoch 1 Batch 211 Loss 7.2436 Accuracy 0.0100
# Epoch 1 Batch 212 Loss 7.2409 Accuracy 0.0101
# Epoch 1 Batch 213 Loss 7.2379 Accuracy 0.0101
# Epoch 1 Batch 214 Loss 7.2348 Accuracy 0.0101
# Epoch 1 Batch 215 Loss 7.2321 Accuracy 0.0101
# Epoch 1 Batch 216 Loss 7.2291 Accuracy 0.0101
# Epoch 1 Batch 217 Loss 7.2259 Accuracy 0.0101
# Epoch 1 Batch 218 Loss 7.2240 Accuracy 0.0101
# Epoch 1 Batch 219 Loss 7.2194 Accuracy 0.0101
# Epoch 1 Batch 220 Loss 7.2153 Accuracy 0.0101
# Epoch 1 Batch 221 Loss 7.2119 Accuracy 0.0102
# Epoch 1 Batch 222 Loss 7.2076 Accuracy 0.0102
# Epoch 1 Batch 223 Loss 7.2033 Accuracy 0.0102
# Epoch 1 Batch 224 Loss 7.1991 Accuracy 0.0102
# Epoch 1 Batch 225 Loss 7.1958 Accuracy 0.0102
# Epoch 1 Batch 226 Loss 7.1930 Accuracy 0.0102
# Epoch 1 Batch 227 Loss 7.1884 Accuracy 0.0102
# Epoch 1 Batch 228 Loss 7.1839 Accuracy 0.0102
# Epoch 1 Batch 229 Loss 7.1797 Accuracy 0.0102
# Epoch 1 Batch 230 Loss 7.1769 Accuracy 0.0103
# Epoch 1 Batch 231 Loss 7.1744 Accuracy 0.0103
# Epoch 1 Batch 232 Loss 7.1707 Accuracy 0.0103
# Epoch 1 Batch 233 Loss 7.1661 Accuracy 0.0103
# Epoch 1 Batch 234 Loss 7.1630 Accuracy 0.0103
# Epoch 1 Batch 235 Loss 7.1591 Accuracy 0.0103
# Epoch 1 Batch 236 Loss 7.1562 Accuracy 0.0103
# Epoch 1 Batch 237 Loss 7.1523 Accuracy 0.0104
# Epoch 1 Batch 238 Loss 7.1488 Accuracy 0.0104
# Epoch 1 Batch 239 Loss 7.1470 Accuracy 0.0104
# Epoch 1 Batch 240 Loss 7.1438 Accuracy 0.0104
# Epoch 1 Batch 241 Loss 7.1398 Accuracy 0.0104
# Epoch 1 Batch 242 Loss 7.1355 Accuracy 0.0104
# Epoch 1 Batch 243 Loss 7.1316 Accuracy 0.0104
# Epoch 1 Batch 244 Loss 7.1265 Accuracy 0.0104
# Epoch 1 Batch 245 Loss 7.1220 Accuracy 0.0104
# Epoch 1 Batch 246 Loss 7.1183 Accuracy 0.0105
# Epoch 1 Batch 247 Loss 7.1145 Accuracy 0.0105
# Epoch 1 Batch 248 Loss 7.1113 Accuracy 0.0105
# Epoch 1 Batch 249 Loss 7.1086 Accuracy 0.0105
# Epoch 1 Batch 250 Loss 7.1051 Accuracy 0.0105
# Epoch 1 Batch 251 Loss 7.1022 Accuracy 0.0105
# Epoch 1 Batch 252 Loss 7.0990 Accuracy 0.0105
# Epoch 1 Batch 253 Loss 7.0956 Accuracy 0.0105
# Epoch 1 Batch 254 Loss 7.0921 Accuracy 0.0105
# Epoch 1 Batch 255 Loss 7.0891 Accuracy 0.0105
# Epoch 1 Batch 256 Loss 7.0854 Accuracy 0.0105
# Epoch 1 Batch 257 Loss 7.0821 Accuracy 0.0106
# Epoch 1 Batch 258 Loss 7.0785 Accuracy 0.0106
# Epoch 1 Batch 259 Loss 7.0755 Accuracy 0.0106
# Epoch 1 Batch 260 Loss 7.0727 Accuracy 0.0106
# Epoch 1 Batch 261 Loss 7.0693 Accuracy 0.0106
# Epoch 1 Batch 262 Loss 7.0649 Accuracy 0.0106
# Epoch 1 Batch 263 Loss 7.0609 Accuracy 0.0106
# Epoch 1 Batch 264 Loss 7.0564 Accuracy 0.0106
# Epoch 1 Batch 265 Loss 7.0539 Accuracy 0.0107
# Epoch 1 Batch 266 Loss 7.0507 Accuracy 0.0107
# Epoch 1 Batch 267 Loss 7.0469 Accuracy 0.0107
# Epoch 1 Batch 268 Loss 7.0430 Accuracy 0.0107
# Epoch 1 Batch 269 Loss 7.0388 Accuracy 0.0107
# Epoch 1 Batch 270 Loss 7.0341 Accuracy 0.0107
# Epoch 1 Batch 271 Loss 7.0298 Accuracy 0.0107
# Epoch 1 Batch 272 Loss 7.0252 Accuracy 0.0108
# Epoch 1 Batch 273 Loss 7.0213 Accuracy 0.0108
# Epoch 1 Batch 274 Loss 7.0165 Accuracy 0.0108
# Epoch 1 Batch 275 Loss 7.0117 Accuracy 0.0108
# Epoch 1 Batch 276 Loss 7.0081 Accuracy 0.0108
# Epoch 1 Batch 277 Loss 7.0036 Accuracy 0.0108
# Epoch 1 Batch 278 Loss 6.9997 Accuracy 0.0109
# Epoch 1 Batch 279 Loss 6.9952 Accuracy 0.0109
# Epoch 1 Batch 280 Loss 6.9914 Accuracy 0.0109
# Epoch 1 Batch 281 Loss 6.9871 Accuracy 0.0109
# Epoch 1 Batch 282 Loss 6.9830 Accuracy 0.0109
# Epoch 1 Batch 283 Loss 6.9808 Accuracy 0.0109
# Epoch 1 Batch 284 Loss 6.9769 Accuracy 0.0110
# Epoch 1 Batch 285 Loss 6.9724 Accuracy 0.0110
# Epoch 1 Batch 286 Loss 6.9672 Accuracy 0.0110
# Epoch 1 Batch 287 Loss 6.9633 Accuracy 0.0110
# Epoch 1 Batch 288 Loss 6.9598 Accuracy 0.0110
# Epoch 1 Batch 289 Loss 6.9551 Accuracy 0.0111
# Epoch 1 Batch 290 Loss 6.9517 Accuracy 0.0111
# Epoch 1 Batch 291 Loss 6.9477 Accuracy 0.0111
# Epoch 1 Batch 292 Loss 6.9435 Accuracy 0.0111
# Epoch 1 Batch 293 Loss 6.9407 Accuracy 0.0111
# Epoch 1 Batch 294 Loss 6.9366 Accuracy 0.0111
# Epoch 1 Batch 295 Loss 6.9321 Accuracy 0.0112
# Epoch 1 Batch 296 Loss 6.9287 Accuracy 0.0112
# Epoch 1 Batch 297 Loss 6.9248 Accuracy 0.0112
# Epoch 1 Batch 298 Loss 6.9199 Accuracy 0.0112
# Epoch 1 Batch 299 Loss 6.9162 Accuracy 0.0112
# Epoch 1 Batch 300 Loss 6.9122 Accuracy 0.0112
# Epoch 1 Batch 301 Loss 6.9073 Accuracy 0.0113
# Epoch 1 Batch 302 Loss 6.9033 Accuracy 0.0113
# Epoch 1 Batch 303 Loss 6.8990 Accuracy 0.0113
# Epoch 1 Batch 304 Loss 6.8952 Accuracy 0.0113
# Epoch 1 Batch 305 Loss 6.8918 Accuracy 0.0113
# Epoch 1 Batch 306 Loss 6.8878 Accuracy 0.0113
# Epoch 1 Batch 307 Loss 6.8828 Accuracy 0.0114
# Epoch 1 Batch 308 Loss 6.8790 Accuracy 0.0114
# Epoch 1 Batch 309 Loss 6.8744 Accuracy 0.0114
# Epoch 1 Batch 310 Loss 6.8702 Accuracy 0.0114
# Epoch 1 Batch 311 Loss 6.8652 Accuracy 0.0114
# Epoch 1 Batch 312 Loss 6.8609 Accuracy 0.0115
# Epoch 1 Batch 313 Loss 6.8562 Accuracy 0.0115
# Epoch 1 Batch 314 Loss 6.8523 Accuracy 0.0115
# Epoch 1 Batch 315 Loss 6.8478 Accuracy 0.0115
# Epoch 1 Batch 316 Loss 6.8432 Accuracy 0.0115
# Epoch 1 Batch 317 Loss 6.8395 Accuracy 0.0115
# Epoch 1 Batch 318 Loss 6.8358 Accuracy 0.0116
# Epoch 1 Batch 319 Loss 6.8319 Accuracy 0.0116
# Epoch 1 Batch 320 Loss 6.8273 Accuracy 0.0116
# Epoch 1 Batch 321 Loss 6.8221 Accuracy 0.0116
# Epoch 1 Batch 322 Loss 6.8176 Accuracy 0.0116
# Epoch 1 Batch 323 Loss 6.8126 Accuracy 0.0117
# Epoch 1 Batch 324 Loss 6.8089 Accuracy 0.0117
# Epoch 1 Batch 325 Loss 6.8039 Accuracy 0.0117
# Epoch 1 Batch 326 Loss 6.7997 Accuracy 0.0117
# Epoch 1 Batch 327 Loss 6.7950 Accuracy 0.0117
# Epoch 1 Batch 328 Loss 6.7905 Accuracy 0.0117
# Epoch 1 Batch 329 Loss 6.7857 Accuracy 0.0118
# Epoch 1 Batch 330 Loss 6.7821 Accuracy 0.0118
# Epoch 1 Batch 331 Loss 6.7787 Accuracy 0.0118
# Epoch 1 Batch 332 Loss 6.7744 Accuracy 0.0118
# Epoch 1 Batch 333 Loss 6.7700 Accuracy 0.0118
# Epoch 1 Batch 334 Loss 6.7670 Accuracy 0.0118
# Epoch 1 Batch 335 Loss 6.7635 Accuracy 0.0119
# Epoch 1 Batch 336 Loss 6.7594 Accuracy 0.0119
# Epoch 1 Batch 337 Loss 6.7548 Accuracy 0.0119
# Epoch 1 Batch 338 Loss 6.7505 Accuracy 0.0119
# Epoch 1 Batch 339 Loss 6.7465 Accuracy 0.0119
# Epoch 1 Batch 340 Loss 6.7426 Accuracy 0.0120
# Epoch 1 Batch 341 Loss 6.7395 Accuracy 0.0120
# Epoch 1 Batch 342 Loss 6.7350 Accuracy 0.0120
# Epoch 1 Batch 343 Loss 6.7309 Accuracy 0.0120
# Epoch 1 Batch 344 Loss 6.7261 Accuracy 0.0120
# Epoch 1 Batch 345 Loss 6.7222 Accuracy 0.0120
# Epoch 1 Batch 346 Loss 6.7189 Accuracy 0.0121
# Epoch 1 Batch 347 Loss 6.7158 Accuracy 0.0121
# Epoch 1 Batch 348 Loss 6.7111 Accuracy 0.0121
# Epoch 1 Batch 349 Loss 6.7070 Accuracy 0.0121
# Epoch 1 Batch 350 Loss 6.7026 Accuracy 0.0121
# Epoch 1 Batch 351 Loss 6.6989 Accuracy 0.0122
# Epoch 1 Batch 352 Loss 6.6936 Accuracy 0.0122
# Epoch 1 Batch 353 Loss 6.6899 Accuracy 0.0122
# Epoch 1 Batch 354 Loss 6.6854 Accuracy 0.0122
# Epoch 1 Batch 355 Loss 6.6812 Accuracy 0.0122
# Epoch 1 Batch 356 Loss 6.6774 Accuracy 0.0123
# Epoch 1 Batch 357 Loss 6.6737 Accuracy 0.0123
# Epoch 1 Batch 358 Loss 6.6697 Accuracy 0.0123
# Epoch 1 Batch 359 Loss 6.6664 Accuracy 0.0123
# Epoch 1 Batch 360 Loss 6.6634 Accuracy 0.0123
# Epoch 1 Batch 361 Loss 6.6605 Accuracy 0.0123
# Epoch 1 Batch 362 Loss 6.6562 Accuracy 0.0124
# Epoch 1 Batch 363 Loss 6.6519 Accuracy 0.0124
# Epoch 1 Batch 364 Loss 6.6489 Accuracy 0.0124
# Epoch 1 Batch 365 Loss 6.6457 Accuracy 0.0124
# Epoch 1 Batch 366 Loss 6.6416 Accuracy 0.0124
# Epoch 1 Batch 367 Loss 6.6375 Accuracy 0.0125
# Epoch 1 Batch 368 Loss 6.6339 Accuracy 0.0125
# Epoch 1 Batch 369 Loss 6.6296 Accuracy 0.0125
# Epoch 1 Batch 370 Loss 6.6260 Accuracy 0.0125
# Epoch 1 Batch 371 Loss 6.6221 Accuracy 0.0125
# Epoch 1 Batch 372 Loss 6.6185 Accuracy 0.0125
# Epoch 1 Batch 373 Loss 6.6144 Accuracy 0.0126
# Epoch 1 Batch 374 Loss 6.6106 Accuracy 0.0126
# Epoch 1 Batch 375 Loss 6.6063 Accuracy 0.0126
# Epoch 1 Batch 376 Loss 6.6016 Accuracy 0.0126
# Epoch 1 Batch 377 Loss 6.5976 Accuracy 0.0126
# Epoch 1 Batch 378 Loss 6.5931 Accuracy 0.0127
# Epoch 1 Batch 379 Loss 6.5896 Accuracy 0.0127
# Epoch 1 Batch 380 Loss 6.5857 Accuracy 0.0127
# Epoch 1 Batch 381 Loss 6.5811 Accuracy 0.0127
# Epoch 1 Batch 382 Loss 6.5769 Accuracy 0.0127
# Epoch 1 Batch 383 Loss 6.5736 Accuracy 0.0128
# Epoch 1 Batch 384 Loss 6.5693 Accuracy 0.0128
# Epoch 1 Batch 385 Loss 6.5656 Accuracy 0.0128
# Epoch 1 Batch 386 Loss 6.5618 Accuracy 0.0128
# Epoch 1 Batch 387 Loss 6.5583 Accuracy 0.0128
# Epoch 1 Batch 388 Loss 6.5544 Accuracy 0.0128
# Epoch 1 Batch 389 Loss 6.5505 Accuracy 0.0129
# Epoch 1 Batch 390 Loss 6.5461 Accuracy 0.0129
# Epoch 1 Batch 391 Loss 6.5418 Accuracy 0.0129
# Epoch 1 Batch 392 Loss 6.5383 Accuracy 0.0129
# Epoch 1 Batch 393 Loss 6.5340 Accuracy 0.0129
# Epoch 1 Batch 394 Loss 6.5300 Accuracy 0.0129
# Epoch 1 Batch 395 Loss 6.5259 Accuracy 0.0130
# Epoch 1 Batch 396 Loss 6.5221 Accuracy 0.0130
# Epoch 1 Batch 397 Loss 6.5176 Accuracy 0.0130
# Epoch 1 Batch 398 Loss 6.5135 Accuracy 0.0130
# Epoch 1 Batch 399 Loss 6.5093 Accuracy 0.0131
# Epoch 1 Batch 400 Loss 6.5053 Accuracy 0.0131
# Epoch 1 Batch 401 Loss 6.5014 Accuracy 0.0131
# Epoch 1 Batch 402 Loss 6.4982 Accuracy 0.0131
# Epoch 1 Batch 403 Loss 6.4944 Accuracy 0.0131
# Epoch 1 Batch 404 Loss 6.4897 Accuracy 0.0132
# Epoch 1 Batch 405 Loss 6.4856 Accuracy 0.0132
# Epoch 1 Batch 406 Loss 6.4813 Accuracy 0.0132
# Epoch 1 Batch 407 Loss 6.4777 Accuracy 0.0132
# Epoch 1 Batch 408 Loss 6.4739 Accuracy 0.0132
# Epoch 1 Batch 409 Loss 6.4704 Accuracy 0.0133
# Epoch 1 Batch 410 Loss 6.4664 Accuracy 0.0133
# Epoch 1 Batch 411 Loss 6.4625 Accuracy 0.0133
# Epoch 1 Batch 412 Loss 6.4588 Accuracy 0.0133
# Epoch 1 Batch 413 Loss 6.4551 Accuracy 0.0133
# Epoch 1 Batch 414 Loss 6.4511 Accuracy 0.0134
# Epoch 1 Batch 415 Loss 6.4471 Accuracy 0.0134
# Epoch 1 Batch 416 Loss 6.4428 Accuracy 0.0134
# Epoch 1 Batch 417 Loss 6.4390 Accuracy 0.0134
# Epoch 1 Batch 418 Loss 6.4350 Accuracy 0.0134
# Epoch 1 Batch 419 Loss 6.4318 Accuracy 0.0135
# Epoch 1 Batch 420 Loss 6.4281 Accuracy 0.0135
# Epoch 1 Batch 421 Loss 6.4233 Accuracy 0.0135
# Epoch 1 Batch 422 Loss 6.4191 Accuracy 0.0135
# Epoch 1 Batch 423 Loss 6.4150 Accuracy 0.0135
# Epoch 1 Batch 424 Loss 6.4115 Accuracy 0.0136
# Epoch 1 Batch 425 Loss 6.4075 Accuracy 0.0136
# Epoch 1 Batch 426 Loss 6.4036 Accuracy 0.0136
# Epoch 1 Batch 427 Loss 6.3991 Accuracy 0.0136
# Epoch 1 Batch 428 Loss 6.3952 Accuracy 0.0136
# Epoch 1 Batch 429 Loss 6.3911 Accuracy 0.0137
# Epoch 1 Batch 430 Loss 6.3875 Accuracy 0.0137
# Epoch 1 Batch 431 Loss 6.3837 Accuracy 0.0137
# Epoch 1 Batch 432 Loss 6.3797 Accuracy 0.0137
# Epoch 1 Batch 433 Loss 6.3757 Accuracy 0.0138
# Epoch 1 Batch 434 Loss 6.3715 Accuracy 0.0138
# Epoch 1 Batch 435 Loss 6.3675 Accuracy 0.0138
# Epoch 1 Batch 436 Loss 6.3634 Accuracy 0.0138
# Epoch 1 Batch 437 Loss 6.3594 Accuracy 0.0138
# Epoch 1 Batch 438 Loss 6.3558 Accuracy 0.0139
# Epoch 1 Batch 439 Loss 6.3517 Accuracy 0.0139
# Epoch 1 Batch 440 Loss 6.3474 Accuracy 0.0139
# Epoch 1 Batch 441 Loss 6.3437 Accuracy 0.0139
# Epoch 1 Batch 442 Loss 6.3394 Accuracy 0.0140
# Epoch 1 Batch 443 Loss 6.3350 Accuracy 0.0140
# Epoch 1 Batch 444 Loss 6.3312 Accuracy 0.0140
# Epoch 1 Batch 445 Loss 6.3265 Accuracy 0.0140
# Epoch 1 Batch 446 Loss 6.3222 Accuracy 0.0141
# Epoch 1 Batch 447 Loss 6.3180 Accuracy 0.0141
# Epoch 1 Batch 448 Loss 6.3144 Accuracy 0.0141
# Epoch 1 Batch 449 Loss 6.3104 Accuracy 0.0141
# Epoch 1 Batch 450 Loss 6.3063 Accuracy 0.0142
# Epoch 1 Batch 451 Loss 6.3027 Accuracy 0.0142
# Epoch 1 Batch 452 Loss 6.2987 Accuracy 0.0142
# Epoch 1 Batch 453 Loss 6.2941 Accuracy 0.0142
# Epoch 1 Batch 454 Loss 6.2900 Accuracy 0.0142
# Epoch 1 Batch 455 Loss 6.2854 Accuracy 0.0143
# Epoch 1 Batch 456 Loss 6.2816 Accuracy 0.0143
# Epoch 1 Batch 457 Loss 6.2772 Accuracy 0.0143
# Epoch 1 Batch 458 Loss 6.2734 Accuracy 0.0143
# Epoch 1 Batch 459 Loss 6.2695 Accuracy 0.0144
# Epoch 1 Batch 460 Loss 6.2648 Accuracy 0.0144
# Epoch 1 Batch 461 Loss 6.2610 Accuracy 0.0144
# Epoch 1 Batch 462 Loss 6.2565 Accuracy 0.0144
# Epoch 1 Batch 463 Loss 6.2528 Accuracy 0.0145
# Epoch 1 Batch 464 Loss 6.2491 Accuracy 0.0145
# Epoch 1 Batch 465 Loss 6.2458 Accuracy 0.0145
# Epoch 1 Batch 466 Loss 6.2420 Accuracy 0.0145
# Epoch 1 Batch 467 Loss 6.2380 Accuracy 0.0146
# Epoch 1 Batch 468 Loss 6.2338 Accuracy 0.0146
# Epoch 1 Batch 469 Loss 6.2308 Accuracy 0.0146
# Epoch 1 Batch 470 Loss 6.2269 Accuracy 0.0146
# Epoch 1 Batch 471 Loss 6.2230 Accuracy 0.0147
# Epoch 1 Batch 472 Loss 6.2191 Accuracy 0.0147
# Epoch 1 Batch 473 Loss 6.2152 Accuracy 0.0147
# Epoch 1 Batch 474 Loss 6.2111 Accuracy 0.0148
# Epoch 1 Batch 475 Loss 6.2068 Accuracy 0.0148
# Epoch 1 Batch 476 Loss 6.2028 Accuracy 0.0148
# Epoch 1 Batch 477 Loss 6.1990 Accuracy 0.0148
# Epoch 1 Batch 478 Loss 6.1945 Accuracy 0.0149
# Epoch 1 Batch 479 Loss 6.1902 Accuracy 0.0149
# Epoch 1 Batch 480 Loss 6.1861 Accuracy 0.0149
# Epoch 1 Batch 481 Loss 6.1821 Accuracy 0.0149
# Epoch 1 Batch 482 Loss 6.1783 Accuracy 0.0150
# Epoch 1 Batch 483 Loss 6.1745 Accuracy 0.0150
# Epoch 1 Batch 484 Loss 6.1704 Accuracy 0.0150
# Epoch 1 Batch 485 Loss 6.1667 Accuracy 0.0150
# Epoch 1 Batch 486 Loss 6.1628 Accuracy 0.0151
# Epoch 1 Batch 487 Loss 6.1595 Accuracy 0.0151
# Epoch 1 Batch 488 Loss 6.1561 Accuracy 0.0151
# Epoch 1 Batch 489 Loss 6.1519 Accuracy 0.0151
# Epoch 1 Batch 490 Loss 6.1477 Accuracy 0.0152
# Epoch 1 Batch 491 Loss 6.1438 Accuracy 0.0152
# Epoch 1 Batch 492 Loss 6.1396 Accuracy 0.0152
# Epoch 1 Batch 493 Loss 6.1356 Accuracy 0.0153
# Epoch 1 Batch 494 Loss 6.1315 Accuracy 0.0153
# Epoch 1 Batch 495 Loss 6.1274 Accuracy 0.0153
# Epoch 1 Batch 496 Loss 6.1230 Accuracy 0.0153
# Epoch 1 Batch 497 Loss 6.1191 Accuracy 0.0154
# Epoch 1 Batch 498 Loss 6.1150 Accuracy 0.0154
# Epoch 1 Batch 499 Loss 6.1118 Accuracy 0.0154
# Epoch 1 Batch 500 Loss 6.1071 Accuracy 0.0155
# Epoch 1 Batch 501 Loss 6.1035 Accuracy 0.0155
# Epoch 1 Batch 502 Loss 6.0991 Accuracy 0.0155
# Epoch 1 Batch 503 Loss 6.0955 Accuracy 0.0155
# Epoch 1 Batch 504 Loss 6.0913 Accuracy 0.0156
# Epoch 1 Batch 505 Loss 6.0875 Accuracy 0.0156
# Epoch 1 Batch 506 Loss 6.0836 Accuracy 0.0156
# Epoch 1 Batch 507 Loss 6.0797 Accuracy 0.0157
# Epoch 1 Batch 508 Loss 6.0755 Accuracy 0.0157
# Epoch 1 Batch 509 Loss 6.0715 Accuracy 0.0157
# Epoch 1 Batch 510 Loss 6.0676 Accuracy 0.0157
# Epoch 1 Batch 511 Loss 6.0638 Accuracy 0.0158
# Epoch 1 Batch 512 Loss 6.0591 Accuracy 0.0158
# Epoch 1 Batch 513 Loss 6.0553 Accuracy 0.0158
# Epoch 1 Batch 514 Loss 6.0512 Accuracy 0.0159
# Epoch 1 Batch 515 Loss 6.0468 Accuracy 0.0159
# Epoch 1 Batch 516 Loss 6.0428 Accuracy 0.0159
# Epoch 1 Batch 517 Loss 6.0387 Accuracy 0.0160
# Epoch 1 Batch 518 Loss 6.0349 Accuracy 0.0160
# Epoch 1 Batch 519 Loss 6.0311 Accuracy 0.0160
# Epoch 1 Batch 520 Loss 6.0277 Accuracy 0.0160
# Epoch 1 Batch 521 Loss 6.0241 Accuracy 0.0161
# Epoch 1 Batch 522 Loss 6.0204 Accuracy 0.0161
# Epoch 1 Batch 523 Loss 6.0161 Accuracy 0.0161
# Epoch 1 Batch 524 Loss 6.0121 Accuracy 0.0162
# Epoch 1 Batch 525 Loss 6.0084 Accuracy 0.0162
# Epoch 1 Batch 526 Loss 6.0049 Accuracy 0.0162
# Epoch 1 Batch 527 Loss 6.0008 Accuracy 0.0162
# Epoch 1 Batch 528 Loss 5.9970 Accuracy 0.0163
# Epoch 1 Batch 529 Loss 5.9934 Accuracy 0.0163
# Epoch 1 Batch 530 Loss 5.9895 Accuracy 0.0163
# Epoch 1 Batch 531 Loss 5.9859 Accuracy 0.0164
# Epoch 1 Batch 532 Loss 5.9822 Accuracy 0.0164
# Epoch 1 Batch 533 Loss 5.9784 Accuracy 0.0164
# Epoch 1 Batch 534 Loss 5.9744 Accuracy 0.0164
# Epoch 1 Batch 535 Loss 5.9708 Accuracy 0.0165
# Epoch 1 Batch 536 Loss 5.9669 Accuracy 0.0165
# Epoch 1 Batch 537 Loss 5.9631 Accuracy 0.0165
# Epoch 1 Batch 538 Loss 5.9592 Accuracy 0.0165
# Epoch 1 Batch 539 Loss 5.9551 Accuracy 0.0166
# Epoch 1 Batch 540 Loss 5.9506 Accuracy 0.0166
# Epoch 1 Batch 541 Loss 5.9471 Accuracy 0.0166
# Epoch 1 Batch 542 Loss 5.9430 Accuracy 0.0167
# Epoch 1 Batch 543 Loss 5.9394 Accuracy 0.0167
# Epoch 1 Batch 544 Loss 5.9355 Accuracy 0.0167
# Epoch 1 Batch 545 Loss 5.9322 Accuracy 0.0168
# Epoch 1 Batch 546 Loss 5.9281 Accuracy 0.0168
# Epoch 1 Batch 547 Loss 5.9242 Accuracy 0.0168
# Epoch 1 Batch 548 Loss 5.9196 Accuracy 0.0168
# Epoch 1 Batch 549 Loss 5.9159 Accuracy 0.0169
# Epoch 1 Batch 550 Loss 5.9119 Accuracy 0.0169
# Epoch 1 Batch 551 Loss 5.9081 Accuracy 0.0169
# Epoch 1 Batch 552 Loss 5.9045 Accuracy 0.0170
# Epoch 1 Batch 553 Loss 5.9007 Accuracy 0.0170
# Epoch 1 Batch 554 Loss 5.8971 Accuracy 0.0170
# Epoch 1 Batch 555 Loss 5.8933 Accuracy 0.0170
# Epoch 1 Batch 556 Loss 5.8896 Accuracy 0.0170
# Epoch 1 Batch 557 Loss 5.8859 Accuracy 0.0171
# Epoch 1 Batch 558 Loss 5.8826 Accuracy 0.0171
# Epoch 1 Batch 559 Loss 5.8786 Accuracy 0.0171
# Epoch 1 Batch 560 Loss 5.8747 Accuracy 0.0172
# Epoch 1 Batch 561 Loss 5.8712 Accuracy 0.0172
# Epoch 1 Batch 562 Loss 5.8677 Accuracy 0.0172
# Epoch 1 Batch 563 Loss 5.8646 Accuracy 0.0172
# Epoch 1 Batch 564 Loss 5.8611 Accuracy 0.0173
# Epoch 1 Batch 565 Loss 5.8571 Accuracy 0.0173
# Epoch 1 Batch 566 Loss 5.8538 Accuracy 0.0173
# Epoch 1 Batch 567 Loss 5.8499 Accuracy 0.0174
# Epoch 1 Batch 568 Loss 5.8465 Accuracy 0.0174
# Epoch 1 Batch 569 Loss 5.8428 Accuracy 0.0174
# Epoch 1 Batch 570 Loss 5.8392 Accuracy 0.0174
# Epoch 1 Batch 571 Loss 5.8356 Accuracy 0.0175
# Epoch 1 Batch 572 Loss 5.8318 Accuracy 0.0175
# Epoch 1 Batch 573 Loss 5.8284 Accuracy 0.0175
# Epoch 1 Batch 574 Loss 5.8253 Accuracy 0.0176
# Epoch 1 Batch 575 Loss 5.8214 Accuracy 0.0176
# Epoch 1 Batch 576 Loss 5.8173 Accuracy 0.0176
# Epoch 1 Batch 577 Loss 5.8135 Accuracy 0.0176
# Epoch 1 Batch 578 Loss 5.8100 Accuracy 0.0177
# Epoch 1 Batch 579 Loss 5.8062 Accuracy 0.0177
# Epoch 1 Batch 580 Loss 5.8021 Accuracy 0.0177
# Epoch 1 Batch 581 Loss 5.7981 Accuracy 0.0178
# Epoch 1 Batch 582 Loss 5.7943 Accuracy 0.0178
# Epoch 1 Batch 583 Loss 5.7900 Accuracy 0.0178
# Epoch 1 Batch 584 Loss 5.7862 Accuracy 0.0179
# Epoch 1 Batch 585 Loss 5.7822 Accuracy 0.0179
# Epoch 1 Batch 586 Loss 5.7806 Accuracy 0.0179
# Epoch 1 Batch 587 Loss 5.7769 Accuracy 0.0179
# Epoch 1 Batch 588 Loss 5.7733 Accuracy 0.0180
# Epoch 1 Batch 589 Loss 5.7695 Accuracy 0.0180
# Epoch 1 Batch 590 Loss 5.7657 Accuracy 0.0180
# Epoch 1 Batch 591 Loss 5.7624 Accuracy 0.0181
# Epoch 1 Batch 592 Loss 5.7590 Accuracy 0.0181
# Epoch 1 Batch 593 Loss 5.7556 Accuracy 0.0181
# Epoch 1 Batch 594 Loss 5.7526 Accuracy 0.0181
# Epoch 1 Batch 595 Loss 5.7490 Accuracy 0.0182
# Epoch 1 Batch 596 Loss 5.7454 Accuracy 0.0182
# Epoch 1 Batch 597 Loss 5.7416 Accuracy 0.0182
# Epoch 1 Batch 598 Loss 5.7380 Accuracy 0.0182
# Epoch 1 Batch 599 Loss 5.7345 Accuracy 0.0183
# Epoch 1 Batch 600 Loss 5.7308 Accuracy 0.0183
# Epoch 1 Batch 601 Loss 5.7275 Accuracy 0.0183
# Epoch 1 Batch 602 Loss 5.7237 Accuracy 0.0184
# Epoch 1 Batch 603 Loss 5.7201 Accuracy 0.0184
# Epoch 1 Batch 604 Loss 5.7164 Accuracy 0.0184
# Epoch 1 Batch 605 Loss 5.7127 Accuracy 0.0185
# Epoch 1 Batch 606 Loss 5.7095 Accuracy 0.0185
# Epoch 1 Batch 607 Loss 5.7060 Accuracy 0.0185
# Epoch 1 Batch 608 Loss 5.7023 Accuracy 0.0185
# Epoch 1 Batch 609 Loss 5.6987 Accuracy 0.0186
# Epoch 1 Batch 610 Loss 5.6952 Accuracy 0.0186
# Epoch 1 Batch 611 Loss 5.6917 Accuracy 0.0186
# Epoch 1 Batch 612 Loss 5.6881 Accuracy 0.0187
# Epoch 1 Batch 613 Loss 5.6846 Accuracy 0.0187
# Epoch 1 Batch 614 Loss 5.6808 Accuracy 0.0187
# Epoch 1 Batch 615 Loss 5.6774 Accuracy 0.0187
# Epoch 1 Batch 616 Loss 5.6737 Accuracy 0.0188
# Epoch 1 Batch 617 Loss 5.6701 Accuracy 0.0188
# Epoch 1 Batch 618 Loss 5.6671 Accuracy 0.0188
# Epoch 1 Batch 619 Loss 5.6635 Accuracy 0.0189
# Epoch 1 Batch 620 Loss 5.6601 Accuracy 0.0189
# Epoch 1 Batch 621 Loss 5.6569 Accuracy 0.0189
# Epoch 1 Batch 622 Loss 5.6538 Accuracy 0.0189
# Epoch 1 Batch 623 Loss 5.6502 Accuracy 0.0190
# Epoch 1 Batch 624 Loss 5.6467 Accuracy 0.0190
# Epoch 1 Batch 625 Loss 5.6432 Accuracy 0.0190
# Epoch 1 Batch 626 Loss 5.6398 Accuracy 0.0190
# Epoch 1 Batch 627 Loss 5.6362 Accuracy 0.0191
# Epoch 1 Batch 628 Loss 5.6326 Accuracy 0.0191
# Epoch 1 Batch 629 Loss 5.6290 Accuracy 0.0191
# Epoch 1 Batch 630 Loss 5.6250 Accuracy 0.0192
# Epoch 1 Batch 631 Loss 5.6213 Accuracy 0.0192
# Epoch 1 Batch 632 Loss 5.6179 Accuracy 0.0192
# Epoch 1 Batch 633 Loss 5.6143 Accuracy 0.0193
# Epoch 1 Batch 634 Loss 5.6109 Accuracy 0.0193
# Epoch 1 Batch 635 Loss 5.6074 Accuracy 0.0193
# Epoch 1 Batch 636 Loss 5.6038 Accuracy 0.0193
# Epoch 1 Batch 637 Loss 5.6004 Accuracy 0.0194
# Epoch 1 Batch 638 Loss 5.5975 Accuracy 0.0194
# Epoch 1 Batch 639 Loss 5.5939 Accuracy 0.0194
# Epoch 1 Batch 640 Loss 5.5905 Accuracy 0.0195
# Epoch 1 Batch 641 Loss 5.5868 Accuracy 0.0195
# Epoch 1 Batch 642 Loss 5.5835 Accuracy 0.0195
# Epoch 1 Batch 643 Loss 5.5798 Accuracy 0.0195
# Epoch 1 Batch 644 Loss 5.5763 Accuracy 0.0196
# Epoch 1 Batch 645 Loss 5.5728 Accuracy 0.0196
# Epoch 1 Batch 646 Loss 5.5691 Accuracy 0.0196
# Epoch 1 Batch 647 Loss 5.5659 Accuracy 0.0197
# Epoch 1 Batch 648 Loss 5.5625 Accuracy 0.0197
# Epoch 1 Batch 649 Loss 5.5591 Accuracy 0.0197
# Epoch 1 Batch 650 Loss 5.5559 Accuracy 0.0197
# Epoch 1 Batch 651 Loss 5.5530 Accuracy 0.0198
# Epoch 1 Batch 652 Loss 5.5498 Accuracy 0.0198
# Epoch 1 Batch 653 Loss 5.5466 Accuracy 0.0198
# Epoch 1 Batch 654 Loss 5.5432 Accuracy 0.0199
# Epoch 1 Batch 655 Loss 5.5398 Accuracy 0.0199
# Epoch 1 Batch 656 Loss 5.5364 Accuracy 0.0199
# Epoch 1 Batch 657 Loss 5.5332 Accuracy 0.0199
# Epoch 1 Batch 658 Loss 5.5297 Accuracy 0.0200
# Epoch 1 Batch 659 Loss 5.5259 Accuracy 0.0200
# Epoch 1 Batch 660 Loss 5.5227 Accuracy 0.0200
# Epoch 1 Batch 661 Loss 5.5191 Accuracy 0.0201
# Epoch 1 Batch 662 Loss 5.5156 Accuracy 0.0201
# Epoch 1 Batch 663 Loss 5.5125 Accuracy 0.0201
# Epoch 1 Batch 664 Loss 5.5094 Accuracy 0.0201
# Epoch 1 Batch 665 Loss 5.5059 Accuracy 0.0202
# Epoch 1 Batch 666 Loss 5.5023 Accuracy 0.0202
# Epoch 1 Batch 667 Loss 5.4991 Accuracy 0.0202
# Epoch 1 Batch 668 Loss 5.4959 Accuracy 0.0203
# Epoch 1 Batch 669 Loss 5.4924 Accuracy 0.0203
# Epoch 1 Batch 670 Loss 5.4895 Accuracy 0.0203
# Epoch 1 Batch 671 Loss 5.4862 Accuracy 0.0203
# Epoch 1 Batch 672 Loss 5.4829 Accuracy 0.0204
# Epoch 1 Batch 673 Loss 5.4799 Accuracy 0.0204
# Epoch 1 Batch 674 Loss 5.4766 Accuracy 0.0204
# Epoch 1 Batch 675 Loss 5.4731 Accuracy 0.0205
# Epoch 1 Batch 676 Loss 5.4702 Accuracy 0.0205
# Epoch 1 Batch 677 Loss 5.4670 Accuracy 0.0205
# Epoch 1 Batch 678 Loss 5.4638 Accuracy 0.0205
# Epoch 1 Batch 679 Loss 5.4607 Accuracy 0.0206
# Epoch 1 Batch 680 Loss 5.4578 Accuracy 0.0206
# Epoch 1 Batch 681 Loss 5.4547 Accuracy 0.0206
# Epoch 1 Batch 682 Loss 5.4516 Accuracy 0.0206
# Epoch 1 Batch 683 Loss 5.4486 Accuracy 0.0207
# Epoch 1 Batch 684 Loss 5.4452 Accuracy 0.0207
# Epoch 1 Batch 685 Loss 5.4421 Accuracy 0.0207
# Epoch 1 Batch 686 Loss 5.4388 Accuracy 0.0208
# Epoch 1 Batch 687 Loss 5.4349 Accuracy 0.0208
# Epoch 1 Batch 688 Loss 5.4315 Accuracy 0.0208
# Epoch 1 Batch 689 Loss 5.4284 Accuracy 0.0208
# Epoch 1 Batch 690 Loss 5.4253 Accuracy 0.0209
# Epoch 1 Batch 691 Loss 5.4222 Accuracy 0.0209
# Epoch 1 Batch 692 Loss 5.4190 Accuracy 0.0209
# Epoch 1 Batch 693 Loss 5.4161 Accuracy 0.0209
# Epoch 1 Batch 694 Loss 5.4134 Accuracy 0.0210
# Epoch 1 Batch 695 Loss 5.4104 Accuracy 0.0210
# Epoch 1 Batch 696 Loss 5.4070 Accuracy 0.0210
# Epoch 1 Batch 697 Loss 5.4041 Accuracy 0.0210
# Epoch 1 Batch 698 Loss 5.4008 Accuracy 0.0211
# Epoch 1 Batch 699 Loss 5.3976 Accuracy 0.0211
# Epoch 1 Batch 700 Loss 5.3944 Accuracy 0.0211
# Epoch 1 Batch 701 Loss 5.3915 Accuracy 0.0211
# Epoch 1 Batch 702 Loss 5.3884 Accuracy 0.0212
# Epoch 1 Batch 703 Loss 5.3858 Accuracy 0.0212
# Epoch 1 Batch 704 Loss 5.3825 Accuracy 0.0212
# Epoch 1 Batch 705 Loss 5.3796 Accuracy 0.0212
# Epoch 1 Batch 706 Loss 5.3764 Accuracy 0.0213
# Epoch 1 Batch 707 Loss 5.3733 Accuracy 0.0213
# Epoch 1 Batch 708 Loss 5.3704 Accuracy 0.0213
# Epoch 1 Batch 709 Loss 5.3672 Accuracy 0.0214
# Epoch 1 Batch 710 Loss 5.3648 Accuracy 0.0214
# Epoch 1 Batch 711 Loss 5.3619 Accuracy 0.0214
# Epoch 1 Batch 712 Loss 5.3589 Accuracy 0.0214
# Epoch 1 Batch 713 Loss 5.3558 Accuracy 0.0214
# Epoch 1 Batch 714 Loss 5.3527 Accuracy 0.0215
# Epoch 1 Batch 715 Loss 5.3501 Accuracy 0.0215
# Epoch 1 Batch 716 Loss 5.3469 Accuracy 0.0215
# Epoch 1 Batch 717 Loss 5.3440 Accuracy 0.0216
# Epoch 1 Batch 718 Loss 5.3411 Accuracy 0.0216
# Epoch 1 Batch 719 Loss 5.3383 Accuracy 0.0216
# Epoch 1 Batch 720 Loss 5.3356 Accuracy 0.0216
# Epoch 1 Batch 721 Loss 5.3325 Accuracy 0.0216
# Epoch 1 Batch 722 Loss 5.3296 Accuracy 0.0217
# Epoch 1 Batch 723 Loss 5.3266 Accuracy 0.0217
# Epoch 1 Batch 724 Loss 5.3236 Accuracy 0.0217
# Epoch 1 Batch 725 Loss 5.3205 Accuracy 0.0218
# Epoch 1 Batch 726 Loss 5.3174 Accuracy 0.0218
# Epoch 1 Batch 727 Loss 5.3146 Accuracy 0.0218
# Epoch 1 Batch 728 Loss 5.3116 Accuracy 0.0218
# Epoch 1 Batch 729 Loss 5.3087 Accuracy 0.0219
# Epoch 1 Batch 730 Loss 5.3055 Accuracy 0.0219
# Epoch 1 Batch 731 Loss 5.3025 Accuracy 0.0219
# Epoch 1 Batch 732 Loss 5.2996 Accuracy 0.0219
# Epoch 1 Batch 733 Loss 5.2967 Accuracy 0.0220
# Epoch 1 Batch 734 Loss 5.2937 Accuracy 0.0220
# Epoch 1 Batch 735 Loss 5.2905 Accuracy 0.0220
# Epoch 1 Batch 736 Loss 5.2874 Accuracy 0.0220
# Epoch 1 Batch 737 Loss 5.2844 Accuracy 0.0221
# Epoch 1 Batch 738 Loss 5.2813 Accuracy 0.0221
# Epoch 1 Batch 739 Loss 5.2780 Accuracy 0.0221
# Epoch 1 Batch 740 Loss 5.2753 Accuracy 0.0221
# Epoch 1 Batch 741 Loss 5.2719 Accuracy 0.0222
# Epoch 1 Batch 742 Loss 5.2691 Accuracy 0.0222
# Epoch 1 Batch 743 Loss 5.2660 Accuracy 0.0222
# Epoch 1 Batch 744 Loss 5.2630 Accuracy 0.0222
# Epoch 1 Batch 745 Loss 5.2600 Accuracy 0.0223
# Epoch 1 Batch 746 Loss 5.2572 Accuracy 0.0223
# Epoch 1 Batch 747 Loss 5.2543 Accuracy 0.0223
# Epoch 1 Batch 748 Loss 5.2518 Accuracy 0.0223
# Epoch 1 Batch 749 Loss 5.2491 Accuracy 0.0224
# Epoch 1 Batch 750 Loss 5.2458 Accuracy 0.0224
# Epoch 1 Batch 751 Loss 5.2433 Accuracy 0.0224
# Epoch 1 Batch 752 Loss 5.2407 Accuracy 0.0224
# Epoch 1 Batch 753 Loss 5.2382 Accuracy 0.0225
# Epoch 1 Batch 754 Loss 5.2352 Accuracy 0.0225
# Epoch 1 Batch 755 Loss 5.2322 Accuracy 0.0225
# Epoch 1 Batch 756 Loss 5.2292 Accuracy 0.0225
# Epoch 1 Batch 757 Loss 5.2264 Accuracy 0.0226
# Epoch 1 Batch 758 Loss 5.2232 Accuracy 0.0226
# Epoch 1 Batch 759 Loss 5.2201 Accuracy 0.0226
# Epoch 1 Batch 760 Loss 5.2177 Accuracy 0.0226
# Epoch 1 Batch 761 Loss 5.2145 Accuracy 0.0227
# Epoch 1 Batch 762 Loss 5.2117 Accuracy 0.0227
# Epoch 1 Batch 763 Loss 5.2087 Accuracy 0.0227
# Epoch 1 Batch 764 Loss 5.2058 Accuracy 0.0227
# Epoch 1 Batch 765 Loss 5.2034 Accuracy 0.0228
# Epoch 1 Batch 766 Loss 5.2005 Accuracy 0.0228
# Epoch 1 Batch 767 Loss 5.1972 Accuracy 0.0228
# Epoch 1 Batch 768 Loss 5.1943 Accuracy 0.0228
# Epoch 1 Batch 769 Loss 5.1912 Accuracy 0.0229
# Epoch 1 Batch 770 Loss 5.1885 Accuracy 0.0229
# Epoch 1 Batch 771 Loss 5.1863 Accuracy 0.0229
# Epoch 1 Batch 772 Loss 5.1835 Accuracy 0.0229
# Epoch 1 Batch 773 Loss 5.1808 Accuracy 0.0230
# Epoch 1 Batch 774 Loss 5.1780 Accuracy 0.0230
# Epoch 1 Batch 775 Loss 5.1750 Accuracy 0.0230
# Epoch 1 Batch 776 Loss 5.1724 Accuracy 0.0230
# Epoch 1 Batch 777 Loss 5.1696 Accuracy 0.0231
# Epoch 1 Batch 778 Loss 5.1672 Accuracy 0.0231
# Epoch 1 Batch 779 Loss 5.1645 Accuracy 0.0231
# Epoch 1 Batch 780 Loss 5.1621 Accuracy 0.0231
# Epoch 1 Batch 781 Loss 5.1596 Accuracy 0.0232
# Epoch 1 Batch 782 Loss 5.1572 Accuracy 0.0232
# Epoch 1 Batch 783 Loss 5.1547 Accuracy 0.0232
# Epoch 1 Batch 784 Loss 5.1520 Accuracy 0.0232
# Epoch 1 Batch 785 Loss 5.1493 Accuracy 0.0232
# Epoch 1 Batch 786 Loss 5.1467 Accuracy 0.0233
# Epoch 1 Batch 787 Loss 5.1444 Accuracy 0.0233
# Epoch 1 Batch 788 Loss 5.1418 Accuracy 0.0233
# Epoch 1 Batch 789 Loss 5.1391 Accuracy 0.0233
# Epoch 1 Batch 790 Loss 5.1362 Accuracy 0.0234
# Epoch 1 Batch 791 Loss 5.1334 Accuracy 0.0234
# Epoch 1 Batch 792 Loss 5.1309 Accuracy 0.0234
# Epoch 1 Batch 793 Loss 5.1283 Accuracy 0.0234
# Epoch 1 Batch 794 Loss 5.1257 Accuracy 0.0235
# Epoch 1 Batch 795 Loss 5.1231 Accuracy 0.0235
# Epoch 1 Batch 796 Loss 5.1203 Accuracy 0.0235
# Epoch 1 Batch 797 Loss 5.1176 Accuracy 0.0235
# Epoch 1 Batch 798 Loss 5.1151 Accuracy 0.0236
# Epoch 1 Batch 799 Loss 5.1125 Accuracy 0.0236
# Epoch 1 Batch 800 Loss 5.1100 Accuracy 0.0236
# Epoch 1 Batch 801 Loss 5.1072 Accuracy 0.0236
# Epoch 1 Batch 802 Loss 5.1045 Accuracy 0.0236
# Epoch 1 Batch 803 Loss 5.1018 Accuracy 0.0237
# Epoch 1 Batch 804 Loss 5.0992 Accuracy 0.0237
# Epoch 1 Batch 805 Loss 5.0964 Accuracy 0.0237
# Epoch 1 Batch 806 Loss 5.0939 Accuracy 0.0237
# Epoch 1 Batch 807 Loss 5.0915 Accuracy 0.0238
# Epoch 1 Batch 808 Loss 5.0892 Accuracy 0.0238
# Epoch 1 Batch 809 Loss 5.0864 Accuracy 0.0238
# Epoch 1 Batch 810 Loss 5.0837 Accuracy 0.0238
# Epoch 1 Batch 811 Loss 5.0811 Accuracy 0.0238
# Epoch 1 Batch 812 Loss 5.0786 Accuracy 0.0239
# Epoch 1 Batch 813 Loss 5.0762 Accuracy 0.0239
# Epoch 1 Batch 814 Loss 5.0733 Accuracy 0.0239
# Epoch 1 Batch 815 Loss 5.0705 Accuracy 0.0239
# Epoch 1 Batch 816 Loss 5.0678 Accuracy 0.0240
# Epoch 1 Batch 817 Loss 5.0654 Accuracy 0.0240
# Epoch 1 Batch 818 Loss 5.0626 Accuracy 0.0240
# Epoch 1 Batch 819 Loss 5.0600 Accuracy 0.0240
# Epoch 1 Batch 820 Loss 5.0575 Accuracy 0.0241
# Epoch 1 Batch 821 Loss 5.0549 Accuracy 0.0241
# Epoch 1 Batch 822 Loss 5.0521 Accuracy 0.0241
# Epoch 1 Batch 823 Loss 5.0497 Accuracy 0.0241
# Epoch 1 Batch 824 Loss 5.0472 Accuracy 0.0241
# Epoch 1 Batch 825 Loss 5.0445 Accuracy 0.0242
# Epoch 1 Batch 826 Loss 5.0420 Accuracy 0.0242
# Epoch 1 Batch 827 Loss 5.0394 Accuracy 0.0242
# Epoch 1 Batch 828 Loss 5.0367 Accuracy 0.0242
# Epoch 1 Batch 829 Loss 5.0346 Accuracy 0.0243
# Epoch 1 Batch 830 Loss 5.0319 Accuracy 0.0243
# Epoch 1 Batch 831 Loss 5.0291 Accuracy 0.0243
# Epoch 1 Batch 832 Loss 5.0267 Accuracy 0.0243
# Epoch 1 Batch 833 Loss 5.0242 Accuracy 0.0244
# Epoch 1 Batch 834 Loss 5.0216 Accuracy 0.0244
# Epoch 1 Batch 835 Loss 5.0189 Accuracy 0.0244
# Epoch 1 Batch 836 Loss 5.0164 Accuracy 0.0244
# Epoch 1 Batch 837 Loss 5.0138 Accuracy 0.0245
# Epoch 1 Batch 838 Loss 5.0112 Accuracy 0.0245
# Epoch 1 Batch 839 Loss 5.0084 Accuracy 0.0245
# Epoch 1 Batch 840 Loss 5.0060 Accuracy 0.0245
# Epoch 1 Batch 841 Loss 5.0039 Accuracy 0.0245
# Epoch 1 Batch 842 Loss 5.0017 Accuracy 0.0246
# Epoch 1 Batch 843 Loss 4.9994 Accuracy 0.0246
# Epoch 1 Batch 844 Loss 4.9971 Accuracy 0.0246
# Epoch 1 Batch 845 Loss 4.9945 Accuracy 0.0246
# Epoch 1 Batch 846 Loss 4.9922 Accuracy 0.0247
# Epoch 1 Batch 847 Loss 4.9901 Accuracy 0.0247
# Epoch 1 Batch 848 Loss 4.9875 Accuracy 0.0247
# Epoch 1 Batch 849 Loss 4.9847 Accuracy 0.0247
# Epoch 1 Batch 850 Loss 4.9823 Accuracy 0.0248
# Epoch 1 Batch 851 Loss 4.9801 Accuracy 0.0248
# Epoch 1 Batch 852 Loss 4.9776 Accuracy 0.0248
# Epoch 1 Batch 853 Loss 4.9748 Accuracy 0.0248
# Epoch 1 Batch 854 Loss 4.9724 Accuracy 0.0248
# Epoch 1 Batch 855 Loss 4.9697 Accuracy 0.0249
# Epoch 1 Batch 856 Loss 4.9671 Accuracy 0.0249
# Epoch 1 Batch 857 Loss 4.9645 Accuracy 0.0249
# Epoch 1 Batch 858 Loss 4.9622 Accuracy 0.0249
# Epoch 1 Batch 859 Loss 4.9600 Accuracy 0.0249
# Epoch 1 Batch 860 Loss 4.9578 Accuracy 0.0250
# Epoch 1 Batch 861 Loss 4.9553 Accuracy 0.0250
# Epoch 1 Batch 862 Loss 4.9527 Accuracy 0.0250
# Epoch 1 Batch 863 Loss 4.9503 Accuracy 0.0250
# Epoch 1 Batch 864 Loss 4.9474 Accuracy 0.0251
# Epoch 1 Batch 865 Loss 4.9448 Accuracy 0.0251
# Epoch 1 Batch 866 Loss 4.9422 Accuracy 0.0251
# Epoch 1 Batch 867 Loss 4.9396 Accuracy 0.0251
# Epoch 1 Batch 868 Loss 4.9371 Accuracy 0.0251
# Epoch 1 Batch 869 Loss 4.9347 Accuracy 0.0252
# Epoch 1 Batch 870 Loss 4.9321 Accuracy 0.0252
# Epoch 1 Batch 871 Loss 4.9298 Accuracy 0.0252
# Epoch 1 Batch 872 Loss 4.9271 Accuracy 0.0252
# Epoch 1 Batch 873 Loss 4.9250 Accuracy 0.0253
# Epoch 1 Batch 874 Loss 4.9228 Accuracy 0.0253
# Epoch 1 Batch 875 Loss 4.9201 Accuracy 0.0253
# Epoch 1 Batch 876 Loss 4.9177 Accuracy 0.0253
# Epoch 1 Batch 877 Loss 4.9150 Accuracy 0.0253
# Epoch 1 Batch 878 Loss 4.9126 Accuracy 0.0254
# Epoch 1 Batch 879 Loss 4.9101 Accuracy 0.0254
# Epoch 1 Batch 880 Loss 4.9080 Accuracy 0.0254
# Epoch 1 Batch 881 Loss 4.9055 Accuracy 0.0254
# Epoch 1 Batch 882 Loss 4.9031 Accuracy 0.0254
# Epoch 1 Batch 883 Loss 4.9009 Accuracy 0.0255
# Epoch 1 Batch 884 Loss 4.8985 Accuracy 0.0255
# Epoch 1 Batch 885 Loss 4.8962 Accuracy 0.0255
# Epoch 1 Batch 886 Loss 4.8937 Accuracy 0.0255
# Epoch 1 Batch 887 Loss 4.8915 Accuracy 0.0255
# Epoch 1 Batch 888 Loss 4.8891 Accuracy 0.0256
# Epoch 1 Batch 889 Loss 4.8866 Accuracy 0.0256
# Epoch 1 Batch 890 Loss 4.8843 Accuracy 0.0256
# Epoch 1 Batch 891 Loss 4.8820 Accuracy 0.0256
# Epoch 1 Batch 892 Loss 4.8800 Accuracy 0.0256
# Epoch 1 Batch 893 Loss 4.8775 Accuracy 0.0257
# Epoch 1 Batch 894 Loss 4.8753 Accuracy 0.0257
# Epoch 1 Batch 895 Loss 4.8731 Accuracy 0.0257
# Epoch 1 Batch 896 Loss 4.8708 Accuracy 0.0257
# Epoch 1 Batch 897 Loss 4.8685 Accuracy 0.0257
# Epoch 1 Batch 898 Loss 4.8662 Accuracy 0.0258
# Epoch 1 Batch 899 Loss 4.8641 Accuracy 0.0258
# Epoch 1 Batch 900 Loss 4.8615 Accuracy 0.0258
# Epoch 1 Batch 901 Loss 4.8593 Accuracy 0.0258
# Epoch 1 Batch 902 Loss 4.8569 Accuracy 0.0258
# Epoch 1 Batch 903 Loss 4.8544 Accuracy 0.0259
# Epoch 1 Batch 904 Loss 4.8520 Accuracy 0.0259
# Epoch 1 Batch 905 Loss 4.8496 Accuracy 0.0259
# Epoch 1 Batch 906 Loss 4.8476 Accuracy 0.0259
# Epoch 1 Batch 907 Loss 4.8454 Accuracy 0.0260
# Epoch 1 Batch 908 Loss 4.8431 Accuracy 0.0260
# Epoch 1 Batch 909 Loss 4.8408 Accuracy 0.0260
# Epoch 1 Batch 910 Loss 4.8385 Accuracy 0.0260
# Epoch 1 Batch 911 Loss 4.8362 Accuracy 0.0260
# Epoch 1 Batch 912 Loss 4.8339 Accuracy 0.0261
# Epoch 1 Batch 913 Loss 4.8318 Accuracy 0.0261
# Epoch 1 Batch 914 Loss 4.8294 Accuracy 0.0261
# Epoch 1 Batch 915 Loss 4.8271 Accuracy 0.0261
# Epoch 1 Batch 916 Loss 4.8251 Accuracy 0.0261
# Epoch 1 Batch 917 Loss 4.8229 Accuracy 0.0262
# Epoch 1 Batch 918 Loss 4.8208 Accuracy 0.0262
# Epoch 1 Batch 919 Loss 4.8184 Accuracy 0.0262
# Epoch 1 Batch 920 Loss 4.8160 Accuracy 0.0262
# Epoch 1 Batch 921 Loss 4.8138 Accuracy 0.0262
# Epoch 1 Batch 922 Loss 4.8116 Accuracy 0.0263
# Epoch 1 Batch 923 Loss 4.8096 Accuracy 0.0263
# Epoch 1 Batch 924 Loss 4.8071 Accuracy 0.0263
# Epoch 1 Batch 925 Loss 4.8050 Accuracy 0.0263
# Epoch 1 Batch 926 Loss 4.8024 Accuracy 0.0263
# Epoch 1 Batch 927 Loss 4.8002 Accuracy 0.0264
# Epoch 1 Batch 928 Loss 4.7979 Accuracy 0.0264
# Epoch 1 Batch 929 Loss 4.7957 Accuracy 0.0264
# Epoch 1 Batch 930 Loss 4.7931 Accuracy 0.0264
# Epoch 1 Batch 931 Loss 4.7908 Accuracy 0.0264
# Epoch 1 Batch 932 Loss 4.7890 Accuracy 0.0264
# Epoch 1 Batch 933 Loss 4.7866 Accuracy 0.0265
# Epoch 1 Batch 934 Loss 4.7842 Accuracy 0.0265
# Epoch 1 Batch 935 Loss 4.7820 Accuracy 0.0265
# Epoch 1 Batch 936 Loss 4.7796 Accuracy 0.0265
# Epoch 1 Batch 937 Loss 4.7774 Accuracy 0.0265
# Epoch 1 Batch 938 Loss 4.7752 Accuracy 0.0266
# Epoch 1 Batch 939 Loss 4.7734 Accuracy 0.0266
# Epoch 1 Batch 940 Loss 4.7711 Accuracy 0.0266
# Epoch 1 Batch 941 Loss 4.7688 Accuracy 0.0266
# Epoch 1 Batch 942 Loss 4.7667 Accuracy 0.0266
# Epoch 1 Batch 943 Loss 4.7645 Accuracy 0.0267
# Epoch 1 Batch 944 Loss 4.7626 Accuracy 0.0267
# Epoch 1 Batch 945 Loss 4.7605 Accuracy 0.0267
# Epoch 1 Batch 946 Loss 4.7584 Accuracy 0.0267
# Epoch 1 Batch 947 Loss 4.7560 Accuracy 0.0267
# Epoch 1 Batch 948 Loss 4.7537 Accuracy 0.0268
# Epoch 1 Batch 949 Loss 4.7514 Accuracy 0.0268
# Epoch 1 Batch 950 Loss 4.7493 Accuracy 0.0268
# Epoch 1 Batch 951 Loss 4.7475 Accuracy 0.0268
# Epoch 1 Batch 952 Loss 4.7452 Accuracy 0.0268
# Epoch 1 Batch 953 Loss 4.7429 Accuracy 0.0269
# Epoch 1 Batch 954 Loss 4.7411 Accuracy 0.0269
# Epoch 1 Batch 955 Loss 4.7389 Accuracy 0.0269
# Epoch 1 Batch 956 Loss 4.7366 Accuracy 0.0269
# Epoch 1 Batch 957 Loss 4.7342 Accuracy 0.0269
# Epoch 1 Batch 958 Loss 4.7319 Accuracy 0.0270
# Epoch 1 Batch 959 Loss 4.7299 Accuracy 0.0270
# Epoch 1 Batch 960 Loss 4.7277 Accuracy 0.0270
# Epoch 1 Batch 961 Loss 4.7255 Accuracy 0.0270
# Epoch 1 Batch 962 Loss 4.7234 Accuracy 0.0270
# Epoch 1 Batch 963 Loss 4.7212 Accuracy 0.0270
# Epoch 1 Batch 964 Loss 4.7189 Accuracy 0.0271
# Epoch 1 Batch 965 Loss 4.7169 Accuracy 0.0271
# Epoch 1 Batch 966 Loss 4.7147 Accuracy 0.0271
# Epoch 1 Batch 967 Loss 4.7123 Accuracy 0.0271
# Epoch 1 Batch 968 Loss 4.7101 Accuracy 0.0271
# Epoch 1 Batch 969 Loss 4.7081 Accuracy 0.0272
# Epoch 1 Batch 970 Loss 4.7059 Accuracy 0.0272
# Epoch 1 Batch 971 Loss 4.7038 Accuracy 0.0272
# Epoch 1 Batch 972 Loss 4.7019 Accuracy 0.0272
# Epoch 1 Batch 973 Loss 4.6999 Accuracy 0.0272
# Epoch 1 Batch 974 Loss 4.6980 Accuracy 0.0272
# Epoch 1 Batch 975 Loss 4.6961 Accuracy 0.0273
# Epoch 1 Batch 976 Loss 4.6939 Accuracy 0.0273
# Epoch 1 Batch 977 Loss 4.6920 Accuracy 0.0273
# Epoch 1 Batch 978 Loss 4.6898 Accuracy 0.0273
# Epoch 1 Batch 979 Loss 4.6878 Accuracy 0.0273
# Epoch 1 Batch 980 Loss 4.6858 Accuracy 0.0274
# Epoch 1 Batch 981 Loss 4.6839 Accuracy 0.0274
# Epoch 1 Batch 982 Loss 4.6820 Accuracy 0.0274
# Epoch 1 Batch 983 Loss 4.6798 Accuracy 0.0274
# Epoch 1 Batch 984 Loss 4.6776 Accuracy 0.0274
# Epoch 1 Batch 985 Loss 4.6754 Accuracy 0.0275
# Epoch 1 Batch 986 Loss 4.6731 Accuracy 0.0275
# Epoch 1 Batch 987 Loss 4.6712 Accuracy 0.0275
# Epoch 1 Batch 988 Loss 4.6687 Accuracy 0.0275
# Epoch 1 Batch 989 Loss 4.6668 Accuracy 0.0275
# Epoch 1 Batch 990 Loss 4.6645 Accuracy 0.0275
# Epoch 1 Batch 991 Loss 4.6622 Accuracy 0.0276
# Epoch 1 Batch 992 Loss 4.6603 Accuracy 0.0276
# Epoch 1 Batch 993 Loss 4.6580 Accuracy 0.0276
# Epoch 1 Batch 994 Loss 4.6561 Accuracy 0.0276
# Epoch 1 Batch 995 Loss 4.6540 Accuracy 0.0276
# Epoch 1 Batch 996 Loss 4.6520 Accuracy 0.0277
# Epoch 1 Batch 997 Loss 4.6500 Accuracy 0.0277
# Epoch 1 Batch 998 Loss 4.6479 Accuracy 0.0277
# Epoch 1 Batch 999 Loss 4.6459 Accuracy 0.0277
# Epoch 1 Batch 1000 Loss 4.6437 Accuracy 0.0277
# Epoch 1 Batch 1001 Loss 4.6418 Accuracy 0.0278
# Epoch 1 Batch 1002 Loss 4.6398 Accuracy 0.0278
# Epoch 1 Batch 1003 Loss 4.6375 Accuracy 0.0278
# Epoch 1 Batch 1004 Loss 4.6356 Accuracy 0.0278
# Epoch 1 Batch 1005 Loss 4.6339 Accuracy 0.0278
# Epoch 1 Batch 1006 Loss 4.6318 Accuracy 0.0279
# Epoch 1 Batch 1007 Loss 4.6299 Accuracy 0.0279
# Epoch 1 Batch 1008 Loss 4.6275 Accuracy 0.0279
# Epoch 1 Batch 1009 Loss 4.6253 Accuracy 0.0279
# Epoch 1 Batch 1010 Loss 4.6233 Accuracy 0.0279
# Epoch 1 Batch 1011 Loss 4.6213 Accuracy 0.0279
# Epoch 1 Batch 1012 Loss 4.6193 Accuracy 0.0280
# Epoch 1 Batch 1013 Loss 4.6172 Accuracy 0.0280
# Epoch 1 Batch 1014 Loss 4.6151 Accuracy 0.0280
# Epoch 1 Batch 1015 Loss 4.6132 Accuracy 0.0280
# Epoch 1 Batch 1016 Loss 4.6108 Accuracy 0.0280
# Epoch 1 Batch 1017 Loss 4.6089 Accuracy 0.0281
# Epoch 1 Batch 1018 Loss 4.6069 Accuracy 0.0281
# Epoch 1 Batch 1019 Loss 4.6048 Accuracy 0.0281
# Epoch 1 Batch 1020 Loss 4.6028 Accuracy 0.0281
# Epoch 1 Batch 1021 Loss 4.6010 Accuracy 0.0281
# Epoch 1 Batch 1022 Loss 4.5989 Accuracy 0.0281
# Epoch 1 Batch 1023 Loss 4.5970 Accuracy 0.0282
# Epoch 1 Batch 1024 Loss 4.5949 Accuracy 0.0282
# Epoch 1 Batch 1025 Loss 4.5929 Accuracy 0.0282
# Epoch 1 Batch 1026 Loss 4.5909 Accuracy 0.0282
# Epoch 1 Batch 1027 Loss 4.5890 Accuracy 0.0282
# Epoch 1 Batch 1028 Loss 4.5869 Accuracy 0.0283
# Epoch 1 Batch 1029 Loss 4.5848 Accuracy 0.0283
# Epoch 1 Batch 1030 Loss 4.5831 Accuracy 0.0283
# Epoch 1 Batch 1031 Loss 4.5809 Accuracy 0.0283
# Epoch 1 Batch 1032 Loss 4.5787 Accuracy 0.0283
# Epoch 1 Batch 1033 Loss 4.5765 Accuracy 0.0283
# Epoch 1 Batch 1034 Loss 4.5747 Accuracy 0.0284
# Epoch 1 Batch 1035 Loss 4.5729 Accuracy 0.0284
# Epoch 1 Batch 1036 Loss 4.5708 Accuracy 0.0284
# Epoch 1 Batch 1037 Loss 4.5688 Accuracy 0.0284
# Epoch 1 Batch 1038 Loss 4.5672 Accuracy 0.0284
# ...
# Epoch 10 Batch 3753 Loss 0.0385 Accuracy 0.0726
# Epoch 10 Batch 3754 Loss 0.0385 Accuracy 0.0726
# Epoch 10 Batch 3755 Loss 0.0386 Accuracy 0.0726
# Epoch 10 Batch 3756 Loss 0.0386 Accuracy 0.0726
# Epoch 10 Batch 3757 Loss 0.0386 Accuracy 0.0726
# Epoch 10 Batch 3758 Loss 0.0386 Accuracy 0.0726
# Epoch 10 Batch 3759 Loss 0.0386 Accuracy 0.0726
# Epoch 10 Batch 3760 Loss 0.0386 Accuracy 0.0726
# Epoch 10 Batch 3761 Loss 0.0386 Accuracy 0.0726
# Epoch 10 Batch 3762 Loss 0.0386 Accuracy 0.0726
# Epoch 10 Batch 3763 Loss 0.0386 Accuracy 0.0726
# Epoch 10 Batch 3764 Loss 0.0386 Accuracy 0.0726
# Epoch 10 Batch 3765 Loss 0.0386 Accuracy 0.0726
# Epoch 10 Batch 3766 Loss 0.0386 Accuracy 0.0726
# Epoch 10 Batch 3767 Loss 0.0386 Accuracy 0.0726
# Epoch 10 Batch 3768 Loss 0.0386 Accuracy 0.0726
# Epoch 10 Batch 3769 Loss 0.0386 Accuracy 0.0726
# Epoch 10 Batch 3770 Loss 0.0386 Accuracy 0.0726
# Epoch 10 Batch 3771 Loss 0.0386 Accuracy 0.0726
# Epoch 10 Batch 3772 Loss 0.0386 Accuracy 0.0726
# Epoch 10 Batch 3773 Loss 0.0386 Accuracy 0.0726
# Epoch 10 Batch 3774 Loss 0.0386 Accuracy 0.0726
# Epoch 10 Batch 3775 Loss 0.0386 Accuracy 0.0726
# Epoch 10 Batch 3776 Loss 0.0386 Accuracy 0.0726
# Epoch 10 Batch 3777 Loss 0.0386 Accuracy 0.0726
# Epoch 10 Batch 3778 Loss 0.0386 Accuracy 0.0726
# Epoch 10 Batch 3779 Loss 0.0386 Accuracy 0.0726
# Epoch 10 Batch 3780 Loss 0.0386 Accuracy 0.0726
# Epoch 10 Batch 3781 Loss 0.0386 Accuracy 0.0726
# Epoch 10 Batch 3782 Loss 0.0386 Accuracy 0.0726
# Epoch 10 Batch 3783 Loss 0.0386 Accuracy 0.0726
# Epoch 10 Batch 3784 Loss 0.0386 Accuracy 0.0726
# Epoch 10 Batch 3785 Loss 0.0386 Accuracy 0.0726
# Epoch 10 Batch 3786 Loss 0.0386 Accuracy 0.0726
# Epoch 10 Batch 3787 Loss 0.0386 Accuracy 0.0726
# Epoch 10 Batch 3788 Loss 0.0386 Accuracy 0.0726
# Epoch 10 Batch 3789 Loss 0.0386 Accuracy 0.0726
# Epoch 10 Batch 3790 Loss 0.0386 Accuracy 0.0726
# Epoch 10 Batch 3791 Loss 0.0386 Accuracy 0.0726
# Epoch 10 Batch 3792 Loss 0.0386 Accuracy 0.0726
# Epoch 10 Batch 3793 Loss 0.0386 Accuracy 0.0726
# Epoch 10 Batch 3794 Loss 0.0386 Accuracy 0.0726
# Epoch 10 Batch 3795 Loss 0.0386 Accuracy 0.0726
# Epoch 10 Batch 3796 Loss 0.0386 Accuracy 0.0726
# Epoch 10 Batch 3797 Loss 0.0386 Accuracy 0.0726
# Epoch 10 Batch 3798 Loss 0.0386 Accuracy 0.0726
# Epoch 10 Batch 3799 Loss 0.0386 Accuracy 0.0726
# Epoch 10 Batch 3800 Loss 0.0387 Accuracy 0.0726
# Epoch 10 Batch 3801 Loss 0.0387 Accuracy 0.0726
# Epoch 10 Batch 3802 Loss 0.0387 Accuracy 0.0726
# Epoch 10 Batch 3803 Loss 0.0387 Accuracy 0.0726
# Epoch 10 Batch 3804 Loss 0.0387 Accuracy 0.0726
# Epoch 10 Batch 3805 Loss 0.0387 Accuracy 0.0726
# Epoch 10 Batch 3806 Loss 0.0387 Accuracy 0.0726
# Epoch 10 Batch 3807 Loss 0.0387 Accuracy 0.0726
# Epoch 10 Batch 3808 Loss 0.0387 Accuracy 0.0726
# Epoch 10 Batch 3809 Loss 0.0387 Accuracy 0.0726
# Epoch 10 Batch 3810 Loss 0.0387 Accuracy 0.0726
# Epoch 10 Batch 3811 Loss 0.0387 Accuracy 0.0726
# Epoch 10 Batch 3812 Loss 0.0387 Accuracy 0.0726
# Epoch 10 Batch 3813 Loss 0.0387 Accuracy 0.0726
# Epoch 10 Batch 3814 Loss 0.0387 Accuracy 0.0726
# Epoch 10 Batch 3815 Loss 0.0387 Accuracy 0.0726
# Epoch 10 Batch 3816 Loss 0.0387 Accuracy 0.0726
# Epoch 10 Batch 3817 Loss 0.0387 Accuracy 0.0726
# Epoch 10 Batch 3818 Loss 0.0387 Accuracy 0.0726
# Epoch 10 Batch 3819 Loss 0.0387 Accuracy 0.0726
# Epoch 10 Batch 3820 Loss 0.0387 Accuracy 0.0726
# Epoch 10 Batch 3821 Loss 0.0387 Accuracy 0.0726
# Epoch 10 Batch 3822 Loss 0.0387 Accuracy 0.0726
# Epoch 10 Batch 3823 Loss 0.0387 Accuracy 0.0726
# Epoch 10 Batch 3824 Loss 0.0387 Accuracy 0.0726
# Epoch 10 Batch 3825 Loss 0.0387 Accuracy 0.0726
# Epoch 10 Batch 3826 Loss 0.0387 Accuracy 0.0726
# Epoch 10 Batch 3827 Loss 0.0387 Accuracy 0.0726
# Epoch 10 Batch 3828 Loss 0.0387 Accuracy 0.0726
# Epoch 10 Batch 3829 Loss 0.0387 Accuracy 0.0726
# Epoch 10 Batch 3830 Loss 0.0387 Accuracy 0.0726
# Epoch 10 Batch 3831 Loss 0.0387 Accuracy 0.0726
# Epoch 10 Batch 3832 Loss 0.0387 Accuracy 0.0726
# Epoch 10 Batch 3833 Loss 0.0387 Accuracy 0.0726
# Epoch 10 Batch 3834 Loss 0.0387 Accuracy 0.0726
# Epoch 10 Batch 3835 Loss 0.0387 Accuracy 0.0726
# Epoch 10 Batch 3836 Loss 0.0387 Accuracy 0.0726
# Epoch 10 Batch 3837 Loss 0.0387 Accuracy 0.0726
# Epoch 10 Batch 3838 Loss 0.0387 Accuracy 0.0726
# Epoch 10 Batch 3839 Loss 0.0387 Accuracy 0.0726
# Epoch 10 Batch 3840 Loss 0.0387 Accuracy 0.0726
# Epoch 10 Batch 3841 Loss 0.0387 Accuracy 0.0726
# Epoch 10 Batch 3842 Loss 0.0387 Accuracy 0.0726
# Epoch 10 Batch 3843 Loss 0.0387 Accuracy 0.0726
# Epoch 10 Batch 3844 Loss 0.0387 Accuracy 0.0726
# Epoch 10 Batch 3845 Loss 0.0387 Accuracy 0.0726
# Epoch 10 Batch 3846 Loss 0.0387 Accuracy 0.0726
# Epoch 10 Batch 3847 Loss 0.0388 Accuracy 0.0726
# Epoch 10 Batch 3848 Loss 0.0388 Accuracy 0.0726
# Epoch 10 Batch 3849 Loss 0.0388 Accuracy 0.0726
# Epoch 10 Batch 3850 Loss 0.0388 Accuracy 0.0726
# Epoch 10 Batch 3851 Loss 0.0388 Accuracy 0.0726
# Epoch 10 Batch 3852 Loss 0.0388 Accuracy 0.0726
# Epoch 10 Batch 3853 Loss 0.0388 Accuracy 0.0726
# Epoch 10 Batch 3854 Loss 0.0388 Accuracy 0.0726
# Epoch 10 Batch 3855 Loss 0.0388 Accuracy 0.0726
# Epoch 10 Batch 3856 Loss 0.0388 Accuracy 0.0726
# Epoch 10 Batch 3857 Loss 0.0388 Accuracy 0.0726
# Epoch 10 Batch 3858 Loss 0.0388 Accuracy 0.0726
# Epoch 10 Batch 3859 Loss 0.0388 Accuracy 0.0726
# Epoch 10 Batch 3860 Loss 0.0388 Accuracy 0.0726
# Epoch 10 Batch 3861 Loss 0.0388 Accuracy 0.0726
# Epoch 10 Batch 3862 Loss 0.0388 Accuracy 0.0726
# Epoch 10 Batch 3863 Loss 0.0388 Accuracy 0.0726
# Epoch 10 Batch 3864 Loss 0.0388 Accuracy 0.0726
# Epoch 10 Batch 3865 Loss 0.0388 Accuracy 0.0726
# Epoch 10 Batch 3866 Loss 0.0388 Accuracy 0.0726
# Epoch 10 Batch 3867 Loss 0.0388 Accuracy 0.0726
# Epoch 10 Batch 3868 Loss 0.0388 Accuracy 0.0726
# Epoch 10 Batch 3869 Loss 0.0388 Accuracy 0.0726
# Epoch 10 Batch 3870 Loss 0.0388 Accuracy 0.0726
# Epoch 10 Batch 3871 Loss 0.0388 Accuracy 0.0726
# Epoch 10 Batch 3872 Loss 0.0388 Accuracy 0.0726
# Epoch 10 Batch 3873 Loss 0.0388 Accuracy 0.0726
# Epoch 10 Batch 3874 Loss 0.0388 Accuracy 0.0726
# Epoch 10 Batch 3875 Loss 0.0389 Accuracy 0.0726
# Epoch 10 Batch 3876 Loss 0.0389 Accuracy 0.0726
# Epoch 10 Batch 3877 Loss 0.0389 Accuracy 0.0726
# Epoch 10 Batch 3878 Loss 0.0389 Accuracy 0.0726
# Epoch 10 Batch 3879 Loss 0.0389 Accuracy 0.0726
# Epoch 10 Batch 3880 Loss 0.0389 Accuracy 0.0726
# Epoch 10 Batch 3881 Loss 0.0389 Accuracy 0.0726
# Epoch 10 Batch 3882 Loss 0.0389 Accuracy 0.0726
# Epoch 10 Batch 3883 Loss 0.0389 Accuracy 0.0726
# Epoch 10 Batch 3884 Loss 0.0389 Accuracy 0.0726
# Epoch 10 Batch 3885 Loss 0.0389 Accuracy 0.0726
# Epoch 10 Batch 3886 Loss 0.0389 Accuracy 0.0726
# Epoch 10 Batch 3887 Loss 0.0389 Accuracy 0.0726
# Epoch 10 Batch 3888 Loss 0.0389 Accuracy 0.0726
# Epoch 10 Batch 3889 Loss 0.0389 Accuracy 0.0726
# Epoch 10 Batch 3890 Loss 0.0389 Accuracy 0.0726
# Epoch 10 Batch 3891 Loss 0.0389 Accuracy 0.0726
# Epoch 10 Batch 3892 Loss 0.0389 Accuracy 0.0726
# Epoch 10 Batch 3893 Loss 0.0389 Accuracy 0.0726
# Epoch 10 Batch 3894 Loss 0.0389 Accuracy 0.0726
# Epoch 10 Batch 3895 Loss 0.0389 Accuracy 0.0726
# Epoch 10 Batch 3896 Loss 0.0389 Accuracy 0.0726
# Epoch 10 Batch 3897 Loss 0.0389 Accuracy 0.0726
# Epoch 10 Batch 3898 Loss 0.0389 Accuracy 0.0726
# Epoch 10 Batch 3899 Loss 0.0389 Accuracy 0.0726
# Epoch 10 Batch 3900 Loss 0.0389 Accuracy 0.0726
# Epoch 10 Batch 3901 Loss 0.0389 Accuracy 0.0726
# Epoch 10 Batch 3902 Loss 0.0389 Accuracy 0.0726
# Epoch 10 Batch 3903 Loss 0.0389 Accuracy 0.0726
# Epoch 10 Batch 3904 Loss 0.0389 Accuracy 0.0726
# Epoch 10 Batch 3905 Loss 0.0389 Accuracy 0.0726
# Epoch 10 Batch 3906 Loss 0.0389 Accuracy 0.0726
# Epoch 10 Batch 3907 Loss 0.0389 Accuracy 0.0726
# Epoch 10 Batch 3908 Loss 0.0389 Accuracy 0.0726
# Epoch 10 Batch 3909 Loss 0.0389 Accuracy 0.0726
# Epoch 10 Batch 3910 Loss 0.0389 Accuracy 0.0726
# Epoch 10 Batch 3911 Loss 0.0390 Accuracy 0.0726
# Epoch 10 Batch 3912 Loss 0.0390 Accuracy 0.0726
# Epoch 10 Batch 3913 Loss 0.0390 Accuracy 0.0726
# Epoch 10 Batch 3914 Loss 0.0390 Accuracy 0.0726
# Epoch 10 Batch 3915 Loss 0.0390 Accuracy 0.0726
# Epoch 10 Batch 3916 Loss 0.0390 Accuracy 0.0726
# Epoch 10 Batch 3917 Loss 0.0390 Accuracy 0.0726
# Epoch 10 Batch 3918 Loss 0.0390 Accuracy 0.0726
# Epoch 10 Batch 3919 Loss 0.0390 Accuracy 0.0726
# Epoch 10 Batch 3920 Loss 0.0390 Accuracy 0.0726
# Epoch 10 Batch 3921 Loss 0.0390 Accuracy 0.0726
# Epoch 10 Batch 3922 Loss 0.0390 Accuracy 0.0726
# Epoch 10 Batch 3923 Loss 0.0390 Accuracy 0.0726
# Epoch 10 Batch 3924 Loss 0.0390 Accuracy 0.0726
# Epoch 10 Batch 3925 Loss 0.0390 Accuracy 0.0726
# Epoch 10 Batch 3926 Loss 0.0390 Accuracy 0.0726
# Epoch 10 Batch 3927 Loss 0.0390 Accuracy 0.0726
# Epoch 10 Batch 3928 Loss 0.0390 Accuracy 0.0726
# Epoch 10 Batch 3929 Loss 0.0390 Accuracy 0.0726
# Epoch 10 Batch 3930 Loss 0.0390 Accuracy 0.0726
# Epoch 10 Batch 3931 Loss 0.0390 Accuracy 0.0726
# Epoch 10 Batch 3932 Loss 0.0390 Accuracy 0.0726
# Epoch 10 Batch 3933 Loss 0.0390 Accuracy 0.0726
# Epoch 10 Batch 3934 Loss 0.0390 Accuracy 0.0726
# Epoch 10 Batch 3935 Loss 0.0390 Accuracy 0.0726
# Epoch 10 Batch 3936 Loss 0.0390 Accuracy 0.0726
# Epoch 10 Batch 3937 Loss 0.0390 Accuracy 0.0726
# Epoch 10 Batch 3938 Loss 0.0390 Accuracy 0.0726
# Epoch 10 Batch 3939 Loss 0.0390 Accuracy 0.0726
# Epoch 10 Batch 3940 Loss 0.0390 Accuracy 0.0726
# Epoch 10 Batch 3941 Loss 0.0390 Accuracy 0.0726
# Epoch 10 Batch 3942 Loss 0.0390 Accuracy 0.0726
# Epoch 10 Batch 3943 Loss 0.0390 Accuracy 0.0726
# Epoch 10 Batch 3944 Loss 0.0390 Accuracy 0.0726
# Epoch 10 Batch 3945 Loss 0.0390 Accuracy 0.0726
# Epoch 10 Batch 3946 Loss 0.0390 Accuracy 0.0726
# Epoch 10 Batch 3947 Loss 0.0390 Accuracy 0.0726
# Epoch 10 Batch 3948 Loss 0.0390 Accuracy 0.0726
# Epoch 10 Batch 3949 Loss 0.0390 Accuracy 0.0726
# Epoch 10 Batch 3950 Loss 0.0390 Accuracy 0.0726
# Epoch 10 Batch 3951 Loss 0.0390 Accuracy 0.0726
# Epoch 10 Batch 3952 Loss 0.0390 Accuracy 0.0726
# Epoch 10 Batch 3953 Loss 0.0390 Accuracy 0.0726
# Epoch 10 Batch 3954 Loss 0.0390 Accuracy 0.0726
# Epoch 10 Batch 3955 Loss 0.0390 Accuracy 0.0726
# Epoch 10 Batch 3956 Loss 0.0390 Accuracy 0.0726
# Epoch 10 Batch 3957 Loss 0.0390 Accuracy 0.0726
# Epoch 10 Batch 3958 Loss 0.0390 Accuracy 0.0726
# Epoch 10 Batch 3959 Loss 0.0390 Accuracy 0.0726
# Epoch 10 Batch 3960 Loss 0.0390 Accuracy 0.0726
# Epoch 10 Batch 3961 Loss 0.0390 Accuracy 0.0726
# Epoch 10 Batch 3962 Loss 0.0391 Accuracy 0.0726
# Epoch 10 Batch 3963 Loss 0.0391 Accuracy 0.0726
# Epoch 10 Batch 3964 Loss 0.0391 Accuracy 0.0726
# Epoch 10 Batch 3965 Loss 0.0391 Accuracy 0.0726
# Epoch 10 Batch 3966 Loss 0.0391 Accuracy 0.0726
# Epoch 10 Batch 3967 Loss 0.0391 Accuracy 0.0726
# Epoch 10 Batch 3968 Loss 0.0391 Accuracy 0.0726
# Epoch 10 Batch 3969 Loss 0.0391 Accuracy 0.0726
# Epoch 10 Batch 3970 Loss 0.0391 Accuracy 0.0726
# Epoch 10 Batch 3971 Loss 0.0391 Accuracy 0.0726
# Epoch 10 Batch 3972 Loss 0.0391 Accuracy 0.0726
# Epoch 10 Batch 3973 Loss 0.0391 Accuracy 0.0726
# Epoch 10 Batch 3974 Loss 0.0391 Accuracy 0.0726
# Epoch 10 Batch 3975 Loss 0.0391 Accuracy 0.0726
# Epoch 10 Batch 3976 Loss 0.0391 Accuracy 0.0726
# Epoch 10 Batch 3977 Loss 0.0391 Accuracy 0.0726
# Epoch 10 Batch 3978 Loss 0.0391 Accuracy 0.0726
# Epoch 10 Batch 3979 Loss 0.0391 Accuracy 0.0726
# Epoch 10 Batch 3980 Loss 0.0391 Accuracy 0.0726
# Epoch 10 Batch 3981 Loss 0.0391 Accuracy 0.0726
# Epoch 10 Batch 3982 Loss 0.0391 Accuracy 0.0726
# Epoch 10 Batch 3983 Loss 0.0391 Accuracy 0.0726
# Epoch 10 Batch 3984 Loss 0.0391 Accuracy 0.0726
# Epoch 10 Batch 3985 Loss 0.0391 Accuracy 0.0726
# Epoch 10 Batch 3986 Loss 0.0391 Accuracy 0.0726
# Epoch 10 Batch 3987 Loss 0.0391 Accuracy 0.0726
# Epoch 10 Batch 3988 Loss 0.0391 Accuracy 0.0726
# Epoch 10 Batch 3989 Loss 0.0391 Accuracy 0.0726
# Epoch 10 Batch 3990 Loss 0.0391 Accuracy 0.0726
# Epoch 10 Batch 3991 Loss 0.0391 Accuracy 0.0726
# Epoch 10 Batch 3992 Loss 0.0391 Accuracy 0.0726
# Epoch 10 Batch 3993 Loss 0.0392 Accuracy 0.0726
# Epoch 10 Batch 3994 Loss 0.0392 Accuracy 0.0726
# Epoch 10 Batch 3995 Loss 0.0392 Accuracy 0.0726
# Epoch 10 Batch 3996 Loss 0.0392 Accuracy 0.0726
# Epoch 10 Batch 3997 Loss 0.0392 Accuracy 0.0726
# Epoch 10 Batch 3998 Loss 0.0392 Accuracy 0.0726
# Epoch 10 Batch 3999 Loss 0.0392 Accuracy 0.0726
# Epoch 10 Batch 4000 Loss 0.0392 Accuracy 0.0726
# Epoch 10 Batch 4001 Loss 0.0392 Accuracy 0.0726
# Epoch 10 Batch 4002 Loss 0.0392 Accuracy 0.0726
# Epoch 10 Batch 4003 Loss 0.0392 Accuracy 0.0726
# Epoch 10 Batch 4004 Loss 0.0392 Accuracy 0.0726
# Epoch 10 Batch 4005 Loss 0.0392 Accuracy 0.0726
# Epoch 10 Batch 4006 Loss 0.0392 Accuracy 0.0726
# Epoch 10 Batch 4007 Loss 0.0392 Accuracy 0.0726
# Epoch 10 Batch 4008 Loss 0.0392 Accuracy 0.0726
# Epoch 10 Batch 4009 Loss 0.0392 Accuracy 0.0726
# Epoch 10 Batch 4010 Loss 0.0392 Accuracy 0.0726
# Epoch 10 Batch 4011 Loss 0.0392 Accuracy 0.0726
# Epoch 10 Batch 4012 Loss 0.0392 Accuracy 0.0726
# Epoch 10 Batch 4013 Loss 0.0392 Accuracy 0.0726
# Epoch 10 Batch 4014 Loss 0.0392 Accuracy 0.0726
# Epoch 10 Batch 4015 Loss 0.0392 Accuracy 0.0726
# Epoch 10 Batch 4016 Loss 0.0392 Accuracy 0.0726
# Epoch 10 Batch 4017 Loss 0.0392 Accuracy 0.0726
# Epoch 10 Batch 4018 Loss 0.0392 Accuracy 0.0726
# Epoch 10 Batch 4019 Loss 0.0392 Accuracy 0.0726
# Epoch 10 Batch 4020 Loss 0.0392 Accuracy 0.0726
# Epoch 10 Batch 4021 Loss 0.0392 Accuracy 0.0726
# Epoch 10 Batch 4022 Loss 0.0392 Accuracy 0.0726
# Epoch 10 Batch 4023 Loss 0.0392 Accuracy 0.0726
# Epoch 10 Batch 4024 Loss 0.0392 Accuracy 0.0726
# Epoch 10 Batch 4025 Loss 0.0392 Accuracy 0.0726
# Epoch 10 Batch 4026 Loss 0.0392 Accuracy 0.0726
# Epoch 10 Batch 4027 Loss 0.0392 Accuracy 0.0726
# Epoch 10 Batch 4028 Loss 0.0392 Accuracy 0.0726
# Epoch 10 Batch 4029 Loss 0.0392 Accuracy 0.0726
# Epoch 10 Batch 4030 Loss 0.0392 Accuracy 0.0726
# Epoch 10 Batch 4031 Loss 0.0392 Accuracy 0.0726
# Epoch 10 Batch 4032 Loss 0.0392 Accuracy 0.0726
# Epoch 10 Batch 4033 Loss 0.0392 Accuracy 0.0726
# Epoch 10 Batch 4034 Loss 0.0392 Accuracy 0.0726
# Epoch 10 Batch 4035 Loss 0.0392 Accuracy 0.0726
# Epoch 10 Batch 4036 Loss 0.0392 Accuracy 0.0726
# Epoch 10 Batch 4037 Loss 0.0392 Accuracy 0.0726
# Epoch 10 Batch 4038 Loss 0.0392 Accuracy 0.0726
# Epoch 10 Batch 4039 Loss 0.0392 Accuracy 0.0726
# Epoch 10 Batch 4040 Loss 0.0392 Accuracy 0.0726
# Epoch 10 Batch 4041 Loss 0.0392 Accuracy 0.0726
# Epoch 10 Batch 4042 Loss 0.0392 Accuracy 0.0726
# Epoch 10 Batch 4043 Loss 0.0392 Accuracy 0.0726
# Epoch 10 Batch 4044 Loss 0.0392 Accuracy 0.0726
# Epoch 10 Batch 4045 Loss 0.0392 Accuracy 0.0726
# Epoch 10 Batch 4046 Loss 0.0392 Accuracy 0.0726
# Epoch 10 Batch 4047 Loss 0.0392 Accuracy 0.0726
# Epoch 10 Batch 4048 Loss 0.0392 Accuracy 0.0726
# Epoch 10 Batch 4049 Loss 0.0392 Accuracy 0.0726
# Epoch 10 Batch 4050 Loss 0.0392 Accuracy 0.0726
# Epoch 10 Batch 4051 Loss 0.0392 Accuracy 0.0726
# Epoch 10 Batch 4052 Loss 0.0392 Accuracy 0.0726
# Epoch 10 Batch 4053 Loss 0.0392 Accuracy 0.0726
# Epoch 10 Batch 4054 Loss 0.0392 Accuracy 0.0726
# Epoch 10 Batch 4055 Loss 0.0392 Accuracy 0.0725
# Epoch 10 Batch 4056 Loss 0.0392 Accuracy 0.0725
# Epoch 10 Batch 4057 Loss 0.0392 Accuracy 0.0725
# Epoch 10 Batch 4058 Loss 0.0392 Accuracy 0.0725
# Epoch 10 Batch 4059 Loss 0.0392 Accuracy 0.0725
# Epoch 10 Batch 4060 Loss 0.0392 Accuracy 0.0725
# Epoch 10 Batch 4061 Loss 0.0392 Accuracy 0.0725
# Epoch 10 Batch 4062 Loss 0.0392 Accuracy 0.0725
# Epoch 10 Batch 4063 Loss 0.0392 Accuracy 0.0725
# Epoch 10 Batch 4064 Loss 0.0392 Accuracy 0.0725
# Epoch 10 Batch 4065 Loss 0.0392 Accuracy 0.0725
# Epoch 10 Batch 4066 Loss 0.0392 Accuracy 0.0725
# Epoch 10 Batch 4067 Loss 0.0393 Accuracy 0.0725
# Epoch 10 Batch 4068 Loss 0.0392 Accuracy 0.0725
# Epoch 10 Batch 4069 Loss 0.0393 Accuracy 0.0725
# Epoch 10 Batch 4070 Loss 0.0393 Accuracy 0.0725
# Epoch 10 Batch 4071 Loss 0.0393 Accuracy 0.0725
# Epoch 10 Batch 4072 Loss 0.0393 Accuracy 0.0725
# Epoch 10 Batch 4073 Loss 0.0393 Accuracy 0.0725
# Epoch 10 Batch 4074 Loss 0.0393 Accuracy 0.0725
# Epoch 10 Batch 4075 Loss 0.0393 Accuracy 0.0725
# Epoch 10 Batch 4076 Loss 0.0393 Accuracy 0.0725
# Epoch 10 Batch 4077 Loss 0.0393 Accuracy 0.0725
# Epoch 10 Batch 4078 Loss 0.0393 Accuracy 0.0725
# Epoch 10 Batch 4079 Loss 0.0393 Accuracy 0.0725
# Epoch 10 Batch 4080 Loss 0.0393 Accuracy 0.0725
# Epoch 10 Batch 4081 Loss 0.0393 Accuracy 0.0725
# Epoch 10 Batch 4082 Loss 0.0393 Accuracy 0.0725
# Epoch 10 Batch 4083 Loss 0.0393 Accuracy 0.0725
# Epoch 10 Batch 4084 Loss 0.0393 Accuracy 0.0725
# Epoch 10 Loss 0.0393 Accuracy 0.0725

# %%
def translate_sentence(model, input_sentence, german_tokenizer, max_len):
    # Pad the input_sentence to max_len
    padded_sentence = pad_sequences(input_sentence, maxlen=max_len, padding='post', truncating='post')

    # Encode the input sentence
    input_sequence = tf.convert_to_tensor(np.array(padded_sentence))  # Add batch dimension

    # Initialize the decoder input with the start token and pad it
    decoder_input_tokens = [german_tokenizer.word_index['<start>']]
    decoder_input_padded = pad_sequences([decoder_input_tokens], maxlen=max_len - 1, padding='post', truncating='post')
    decoder_input = tf.convert_to_tensor(decoder_input_padded)

    # Print the shape of input_sequence and decoder_input
    print("Input sequence shape:", input_sequence.shape)
    print("Decoder input shape:", decoder_input.shape)

    # Initialize the output German sentence
    output_sentence = []

    for _ in range(max_len):
        # Make a prediction
        predictions = model((input_sequence, decoder_input), training=False)

        # Get the index of the most probable token
        predicted_token_index = tf.argmax(predictions[:, -1, :], axis=-1).numpy()[0]

        # Check if the predicted token is the end token
        if german_tokenizer.index_word[predicted_token_index] == '<end>':
            break

        # Add the predicted token to the output sentence
        output_sentence.append(german_tokenizer.index_word[predicted_token_index])

        # Update the decoder input with the predicted token
        decoder_input_tokens.append(predicted_token_index)
        decoder_input_padded = pad_sequences([decoder_input_tokens], maxlen=max_len - 1, padding='post', truncating='post')
        decoder_input = tf.convert_to_tensor(decoder_input_padded)

    # Convert the output sentence to German text
    output_text = ' '.join(output_sentence)

    print("Translated sentence:", output_text)

# %%
# Tokenize and pad a sample English sentence
english_sentence = "I love it."
tokenized_sentence = english_tokenizer.texts_to_sequences([english_sentence])

# Translate the sentence
translate_sentence(trained_model, tokenized_sentence, german_tokenizer, max_len)
# Out:
# Input sequence shape: (1, 101)
# Decoder input shape: (1, 100)
# Translated sentence: Fremdsprachen Fremdsprachen Fremdsprachen Fremdsprachen Fremdsprachen Fremdsprachen Fremdsprachen Fremdsprachen Fremdsprachen Fremdsprachen Fremdsprachen Fremdsprachen Fremdsprachen Fremdsprachen Fremdsprachen Fremdsprachen Fremdsprachen Fremdsprachen Fremdsprachen Fremdsprachen Fremdsprachen Fremdsprachen Fremdsprachen Fremdsprachen Fremdsprachen Fremdsprachen Fremdsprachen Fremdsprachen Fremdsprachen Fremdsprachen Fremdsprachen Fremdsprachen Fremdsprachen Fremdsprachen Fremdsprachen Fremdsprachen Fremdsprachen Fremdsprachen Fremdsprachen Fremdsprachen Fremdsprachen Fremdsprachen Fremdsprachen Fremdsprachen Fremdsprachen Fremdsprachen Fremdsprachen Fremdsprachen Fremdsprachen Fremdsprachen Fremdsprachen Fremdsprachen Fremdsprachen Fremdsprachen Fremdsprachen Fremdsprachen Fremdsprachen Fremdsprachen Fremdsprachen Fremdsprachen Fremdsprachen Fremdsprachen Fremdsprachen Fremdsprachen Fremdsprachen Fremdsprachen Fremdsprachen Fremdsprachen Fremdsprachen Fremdsprachen Fremdsprachen Fremdsprachen Fremdsprachen Fremdsprachen Fremdsprachen Fremdsprachen Fremdsprachen Fremdsprachen Fremdsprachen Fremdsprachen Fremdsprachen Fremdsprachen Fremdsprachen Fremdsprachen Fremdsprachen Fremdsprachen Fremdsprachen Fremdsprachen Fremdsprachen Fremdsprachen Fremdsprachen Fremdsprachen Fremdsprachen Fremdsprachen Fremdsprachen Fremdsprachen Fremdsprachen Fremdsprachen Fremdsprachen häufigen häufigen
